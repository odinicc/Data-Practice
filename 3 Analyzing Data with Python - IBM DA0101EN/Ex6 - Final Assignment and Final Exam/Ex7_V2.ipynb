# %%
import pandas as pd
import numpy as np

df = pd.read_csv ('kc_house_data.csv')
print(df)

#check data types
df.dtypes

# %%
#convert values
df['bedrooms'] = df['bedrooms'].astype(np.int64)
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

# %%
df['dateint'] = pd.to_numeric(df['date'])

# %%
df['date']= pd.to_datetime(df['date'])
df['date'] = pd.to_numeric(df['date'])

# %%
#check data types
df.dtypes

# %%
df.corr()

# %%
correlation = df.corr(method='pearson')
columns = correlation.nlargest(10, 'price').index
columns

# %%
y_data = df['price']

# %%
x_data = df[columns]

# %%
X_data.head()

# %%
x_data.head()

# %%
x_data=df.drop('price',axis=1)

# %%
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

# %%
#import libs
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train)
x_test_pr1=pr1.fit_transform(x_test)
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train)
x_test_pr1=pr1.fit_transform(x_test)
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)

# %%
yhat_test = poly1.predict(x_test_pr1)

# %%
poly1.score(x_test_pr1, y_test)

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
import sklearn
from scipy import stats
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
Rsqu_test = []
order = [1, 2, 3, 4]
lr = LinearRegression()
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train)
    x_test_pr = pr.fit_transform(x_test)    
    lr.fit(x_train_pr, y_train)
   
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
# Best order for regression is 2

# %%
plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')

# %%
Rsqu_test = []
order = [1, 2, 3, 4]
lr = LinearRegression()
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train[col_names])
    x_test_pr = pr.fit_transform(x_test[col_names])    
    lr.fit(x_train_pr, y_train)
   
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
Rsqu_test = []
order = [1, 2, 3, 4]
lr = LinearRegression()
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train[col_names])
    x_test_pr = pr.fit_transform(x_test[col_names])    
    lr.fit(x_train_pr, y_train)
   
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')

# %%
from sklearn.preprocessing import PolynomialFeatures

from sklearn.pipeline import make_pipeline

# %%
Rsqu_test = []
order = [1, 2, 3, 4]
lr = LinearRegression()
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train[col_names])
    x_test_pr = pr.fit_transform(x_test[col_names])    
    lr.fit(x_train_pr, y_train)
   
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')

# %%
import pandas as pd
import numpy as np

df = pd.read_csv ('kc_house_data.csv')
print(df)

#check data types
df.dtypes

#convert values
df['bedrooms'] = df['bedrooms'].astype(np.int64)
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

#convert date to int 
df['date']= pd.to_datetime(df['date'])
df['date'] = pd.to_numeric(df['date'])

#check data types
df.dtypes

#check correlation matrix
df.corr()

#find columns with max correlation
correlation = df.corr(method='pearson')
columns = correlation.nlargest(10, 'price').index
columns

#place the target data price in a separate dataframe y_data . x_data
y_data = df['price']
x_data = df[columns]  
x_data=df.drop('price',axis=1)

#split the series 
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

#import libs
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import sklearn
from scipy import stats
import matplotlib.pyplot as plt
import os
import seaborn as sns


#define plot function
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

#Run polinomial regression with order = 2
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train)
x_test_pr1=pr1.fit_transform(x_test)
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)
yhat_test = poly1.predict(x_test_pr1)

#Estimate R2 
poly1.score(x_test_pr1, y_test)

#Draw the graph
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

#POLINOMIAL REGRESSION
# Find the best order for model

# %%
Rsqu_test = []
order = [1, 2, 3, 4]
lr = LinearRegression()
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train)
    x_test_pr = pr.fit_transform(x_test)    
    lr.fit(x_train_pr, y_train)
   
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
# Best order for regression is 2

# %%
Rsqu_test = []
order = [1, 2]
lr = LinearRegression()
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train)
    x_test_pr = pr.fit_transform(x_test)    
    lr.fit(x_train_pr, y_train)
   
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
# Best order for regression is 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7804/529333375.py in <module>
#       1 Rsqu_test = []
#       2 order = [1, 2]
# ----> 3 lr = LinearRegression()
#       4 for n in order:
#       5     pr = PolynomialFeatures(degree=n)
#
# NameError: name 'LinearRegression' is not defined

# %%
import pandas as pd
import numpy as np

df = pd.read_csv ('kc_house_data.csv')
print(df)

#check data types
df.dtypes

#convert values
df['bedrooms'] = df['bedrooms'].astype(np.int64)
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

#convert date to int 
df['date']= pd.to_datetime(df['date'])
df['date'] = pd.to_numeric(df['date'])

#check data types
df.dtypes

#check correlation matrix
df.corr()

#find columns with max correlation
correlation = df.corr(method='pearson')
columns = correlation.nlargest(10, 'price').index
columns

#place the target data price in a separate dataframe y_data . x_data
y_data = df['price']
x_data = df[columns]  
x_data=df.drop('price',axis=1)

#split the series 
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

#import libs
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import sklearn
from scipy import stats
import matplotlib.pyplot as plt
import os
import seaborn as sns


#define plot function
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

#Run polinomial regression with order = 2
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train)
x_test_pr1=pr1.fit_transform(x_test)
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)
yhat_test = poly1.predict(x_test_pr1)

#Estimate R2 
poly1.score(x_test_pr1, y_test)

#Draw the graph
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# Find the best order for model
#POLINOMIAL REGRESSION
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
Rsqu_test = []
order = [1, 2]
lr = LinearRegression()
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train)
    x_test_pr = pr.fit_transform(x_test)    
    lr.fit(x_train_pr, y_train)
   
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
# Best order for regression is 2
# Out:
# Text(0.5, 1.0, 'R^2 Using Test Data')

# %%
Rsqu_test = []
order = [1, 2, 3]
lr = LinearRegression()
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train)
    x_test_pr = pr.fit_transform(x_test)    
    lr.fit(x_train_pr, y_train)
   
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
# Best order for regression is 2
# Out:
# Text(0.5, 1.0, 'R^2 Using Test Data')

# %%
#find missing data in each column
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7804/3998209396.py in <module>
#       1 #find missing data in each column
# ----> 2 for column in missing_data.columns.values.tolist():
#       3     print(column)
#       4     print (missing_data[column].value_counts())
#       5     print("")
#
# NameError: name 'missing_data' is not defined

# %%
import pandas as pd
import numpy as np

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7804/3003615466.py in <module>
# ----> 1 for column in missing_data.columns.values.tolist():
#       2     print(column)
#       3     print (missing_data[column].value_counts())
#       4     print("")
#
# NameError: name 'missing_data' is not defined

# %%
X_train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7804/962641680.py in <module>
# ----> 1 X_train.head()
#
# NameError: name 'X_train' is not defined

# %%
import pandas as pd
import numpy as np

df = pd.read_csv ('kc_house_data.csv')
print(df)

#check data types
df.dtypes

#convert values
df['bedrooms'] = df['bedrooms'].astype(np.int64)
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

#convert date to int 
df['date']= pd.to_datetime(df['date'])
df['date'] = pd.to_numeric(df['date'])

#check data types
df.dtypes

#check correlation matrix
df.corr()

#find columns with max correlation
correlation = df.corr(method='pearson')
columns = correlation.nlargest(10, 'price').index
columns

#place the target data price in a separate dataframe y_data . x_data
y_data = df['price']
x_data = df[columns]  
x_data=df.drop('price',axis=1)

#split the series 
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

#import libs
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import sklearn
from scipy import stats
import matplotlib.pyplot as plt
import os
import seaborn as sns


#define plot function
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

#Run polinomial regression with order = 2
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train)
x_test_pr1=pr1.fit_transform(x_test)
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)
yhat_test = poly1.predict(x_test_pr1)

#Estimate R2 
poly1.score(x_test_pr1, y_test)

#Draw the graph
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# Find the best order for model
#POLINOMIAL REGRESSION
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
x_train.head()
# Out:
#                id                 date  bedrooms  bathrooms  sqft_living  \
# 16973  5561301150  1415664000000000000         5          3         3520
# 14689  8712100760  1411516800000000000         2          1         1790
# 819    1565900070  1405900800000000000         3          2         1430
# 20246  9376301112  1414713600000000000         2          2         1380
# 8084   8146100325  1399248000000000000         3          1         1330
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 16973     36558       2           0     0          4      8        2100
# 14689      4250       1           0     0          3      7         920
# 819        8919       1           0     0          3      7        1430
# 20246      1329       2           0     0          3      8        1050
# 8084       7500       1           0     0          3      8        1330
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 16973           1420      1985             0    98027  47.4658 -122.007
# 14689            870      1915          2014    98112  47.6367 -122.301
# 819                0      1992             0    98022  47.2118 -121.983
# 20246            330      2008             0    98117  47.6903 -122.370
# 8084               0      1961             0    98004  47.6074 -122.195
#
#        sqft_living15  sqft_lot15
# 16973           3000       36558
# 14689           1910        4250
# 819             1580        8919
# 20246           1360        3750
# 8084            1690        7800

# %%
df['date'] = preprocessing.normalize(['date'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7804/1727895058.py in <module>
# ----> 1 df['date'] = preprocessing.normalize(['date'])
#
# NameError: name 'preprocessing' is not defined

# %%
 from sklearn import preprocessing

# %%
df['date'] = preprocessing.normalize(['date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7804/1727895058.py in <module>
# ----> 1 df['date'] = preprocessing.normalize(['date'])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in normalize(X, norm, axis, copy, return_norm)
#    1902         raise ValueError("'%d' is not a supported axis" % axis)
#    1903
# -> 1904     X = check_array(X, accept_sparse=sparse_format, copy=copy,
#    1905                     estimator='the normalize function', dtype=FLOAT_DTYPES)
#    1906     if axis == 0:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'date'

# %%
df.datetype[]
# Out:
#   File "C:\Users\ivan\AppData\Local\Temp/ipykernel_7804/2668607465.py", line 1
#     df.datetype[]
#                 ^
# SyntaxError: invalid syntax

# %%
df.datetype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7804/689944083.py in <module>
# ----> 1 df.datetype
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'datetype'

# %%
df.datetype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7804/3221156194.py in <module>
# ----> 1 df.datetype()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'datetype'

# %%
df.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7804/2494035241.py in <module>
# ----> 1 df.dtype()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7804/1115469300.py in <module>
# ----> 1 df.dtype
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df.dtypes
# Out:
# id                 int64
# date               int64
# price            float64
# bedrooms           int64
# bathrooms          int64
# sqft_living        int64
# sqft_lot           int64
# floors             int64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df_norm = (df - df.mean()) / (df.max() - df.min())

# %%
df = (df - df.mean()) / (df.max() - df.min())

# %%
    import pandas as pd
import numpy as np
from sklearn import preprocessing

df = pd.read_csv ('kc_house_data.csv')
print(df)

#check data types
df.dtypes

#convert values
df['bedrooms'] = df['bedrooms'].astype(np.int64)
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

#convert date to int 
df['date']= pd.to_datetime(df['date'])
df['date'] = pd.to_numeric(df['date'])

#Normalize  dataframe
df_norm = (df - df.mean()) / (df.max() - df.min())

#check data types
df.dtypes

#check correlation matrix
df.corr()

#find columns with max correlation
correlation = df.corr(method='pearson')
columns = correlation.nlargest(10, 'price').index
columns

#place the target data price in a separate dataframe y_data . x_data
y_data = df['price']
x_data = df[columns]  
x_data=df.drop('price',axis=1)

#split the series 
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

#import libs
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import sklearn
from scipy import stats
import matplotlib.pyplot as plt
import os
import seaborn as sns


#define plot function
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

#Run polinomial regression with order = 2
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train)
x_test_pr1=pr1.fit_transform(x_test)
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)
yhat_test = poly1.predict(x_test_pr1)

#Estimate R2 
poly1.score(x_test_pr1, y_test)

#Draw the graph
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# Find the best order for model
#POLINOMIAL REGRESSION
# Out:
#   File "C:\Users\ivan\AppData\Local\Temp/ipykernel_7804/1746140442.py", line 60
#     fig, ax = plt.subplots()
#     ^
# IndentationError: expected an indented block

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

df = pd.read_csv ('kc_house_data.csv')
print(df)

#check data types
df.dtypes

#convert values
df['bedrooms'] = df['bedrooms'].astype(np.int64)
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

#convert date to int 
df['date']= pd.to_datetime(df['date'])
df['date'] = pd.to_numeric(df['date'])

#Normalize  dataframe
df_norm = (df - df.mean()) / (df.max() - df.min())

#check data types
df.dtypes

#check correlation matrix
df.corr()

#find columns with max correlation
correlation = df.corr(method='pearson')
columns = correlation.nlargest(10, 'price').index
columns

#place the target data price in a separate dataframe y_data . x_data
y_data = df['price']
x_data = df[columns]  
x_data=df.drop('price',axis=1)

#split the series 
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

#import libs
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import sklearn
from scipy import stats
import matplotlib.pyplot as plt
import os
import seaborn as sns
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

df = pd.read_csv ('kc_house_data.csv')
print(df)

#check data types
df.dtypes

#convert values
df['bedrooms'] = df['bedrooms'].astype(np.int64)
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

#convert date to int 
df['date']= pd.to_datetime(df['date'])
df['date'] = pd.to_numeric(df['date'])

#Normalize  dataframe
df = (df - df.mean()) / (df.max() - df.min())

#check data types
df.dtypes

#check correlation matrix
df.corr()

#find columns with max correlation
correlation = df.corr(method='pearson')
columns = correlation.nlargest(10, 'price').index
columns

#place the target data price in a separate dataframe y_data . x_data
y_data = df['price']
x_data = df[columns]  
x_data=df.drop('price',axis=1)

#split the series 
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

#import libs
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import sklearn
from scipy import stats
import matplotlib.pyplot as plt
import os
import seaborn as sns
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
df.head()
# Out:
#          id      date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  0.257501 -0.041521 -0.041730 -0.011238  -0.093717    -0.067917 -0.005729
# 1  0.185251  0.104633 -0.000274 -0.011238   0.031283     0.036989 -0.004764
# 2  0.106192  0.304633 -0.047225 -0.041541  -0.093717    -0.098860 -0.003094
# 3 -0.211446  0.104633  0.008382  0.019065   0.156283    -0.009049 -0.006122
# 4 -0.265269  0.286684 -0.003946 -0.011238   0.031283    -0.030181 -0.004257
#
#      floors  waterfront      view  ...     grade  sqft_above  sqft_basement  \
# 0 -0.223106   -0.007542 -0.058576  ... -0.054739   -0.066710      -0.060479
# 1  0.276894   -0.007542 -0.058576  ... -0.054739    0.041843       0.022508
# 2 -0.223106   -0.007542 -0.058576  ... -0.138073   -0.111666      -0.060479
# 3 -0.223106   -0.007542 -0.058576  ... -0.054739   -0.080964       0.128318
# 4 -0.223106   -0.007542 -0.058576  ...  0.028594   -0.011885      -0.060479
#
#    yr_built  yr_renovated   zipcode       lat      long  sqft_living15  \
# 0 -0.139175     -0.041887  0.505355 -0.078579 -0.035800      -0.111264
# 1 -0.173958      0.946202  0.237678  0.258883 -0.087295      -0.051033
# 2 -0.330479     -0.041887 -0.252221  0.286066 -0.015867       0.126217
# 3 -0.052219     -0.041887  0.293233 -0.063137 -0.148757      -0.107822
# 4  0.139086     -0.041887 -0.019898  0.091278  0.140279      -0.032103
#
#    sqft_lot15
# 0   -0.008177
# 1   -0.005892
# 2   -0.005406
# 3   -0.008924
# 4   -0.006048
#
# [5 rows x 21 columns]

# %%
define plot function
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()
# Out:
#   File "C:\Users\ivan\AppData\Local\Temp/ipykernel_7804/1428999468.py", line 1
#     define plot function
#            ^
# SyntaxError: invalid syntax

# %%
#define plot function
    def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
       
        fig, ax = plt.subplots()
        #define first graph style and second graph style
        sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
        sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
        
        #define titles and axis
        plt.title(Title)
        plt.xlabel('Price (in dollars)')
        plt.ylabel('Proportion of flats')
        
        #show plot
        ax.legend()
        plt.show()
        plt.close()
# Out:
#   File "C:\Users\ivan\AppData\Local\Temp/ipykernel_7804/2096506872.py", line 2
#     def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
#     ^
# IndentationError: unexpected indent

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

df = pd.read_csv ('kc_house_data.csv')
print(df)

#check data types
df.dtypes

#convert values
df['bedrooms'] = df['bedrooms'].astype(np.int64)
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

#convert date to int 
df['date']= pd.to_datetime(df['date'])
df['date'] = pd.to_numeric(df['date'])

#Normalize  dataframe
df = (df - df.mean()) / (df.max() - df.min())

#check data types
df.dtypes

#check correlation matrix
df.corr()

#find columns with max correlation
correlation = df.corr(method='pearson')
columns = correlation.nlargest(12, 'price').index
columns

#place the target data price in a separate dataframe y_data . x_data
y_data = df['price']
x_data = df[columns]  
x_data=df.drop('price',axis=1)

#split the series 
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

#import libs
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import sklearn
from scipy import stats
import matplotlib.pyplot as plt
import os import seaborn as sns


def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

#Run polinomial regression with order = 2
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train)
x_test_pr1=pr1.fit_transform(x_test)
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)
yhat_test = poly1.predict(x_test_pr1)

#Estimate R2 
poly1.score(x_test_pr1, y_test)

#Draw the graph
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# Find the best order for model
#POLINOMIAL REGRESSION
# Out:
#   File "C:\Users\ivan\AppData\Local\Temp/ipykernel_7804/806361956.py", line 53
#     import os import seaborn as sns
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import os import seaborn as sns

df = pd.read_csv ('kc_house_data.csv')
print(df)

#check data types
df.dtypes

#convert values
df['bedrooms'] = df['bedrooms'].astype(np.int64)
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

#convert date to int 
df['date']= pd.to_datetime(df['date'])
df['date'] = pd.to_numeric(df['date'])

#Normalize  dataframe
df = (df - df.mean()) / (df.max() - df.min())

#check data types
df.dtypes

#check correlation matrix
df.corr()

#find columns with max correlation
correlation = df.corr(method='pearson')
columns = correlation.nlargest(12, 'price').index
columns

#place the target data price in a separate dataframe y_data . x_data
y_data = df['price']
x_data = df[columns]  
x_data=df.drop('price',axis=1)

#split the series 
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

#import libs
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import sklearn
from scipy import stats
import matplotlib.pyplot as plt



def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

#Run polinomial regression with order = 2
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train)
x_test_pr1=pr1.fit_transform(x_test)
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)
yhat_test = poly1.predict(x_test_pr1)

#Estimate R2 
poly1.score(x_test_pr1, y_test)

#Draw the graph
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# Find the best order for model
#POLINOMIAL REGRESSION
# Out:
#   File "C:\Users\ivan\AppData\Local\Temp/ipykernel_7804/3324913933.py", line 4
#     import os import seaborn as sns
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import os 
import seaborn as sns

df = pd.read_csv ('kc_house_data.csv')
print(df)

#check data types
df.dtypes

#convert values
df['bedrooms'] = df['bedrooms'].astype(np.int64)
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

#convert date to int 
df['date']= pd.to_datetime(df['date'])
df['date'] = pd.to_numeric(df['date'])

#Normalize  dataframe
df = (df - df.mean()) / (df.max() - df.min())

#check data types
df.dtypes

#check correlation matrix
df.corr()

#find columns with max correlation
correlation = df.corr(method='pearson')
columns = correlation.nlargest(12, 'price').index
columns

#place the target data price in a separate dataframe y_data . x_data
y_data = df['price']
x_data = df[columns]  
x_data=df.drop('price',axis=1)

#split the series 
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

#import libs
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import sklearn
from scipy import stats
import matplotlib.pyplot as plt



def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

#Run polinomial regression with order = 2
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train)
x_test_pr1=pr1.fit_transform(x_test)
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)
yhat_test = poly1.predict(x_test_pr1)

#Estimate R2 
poly1.score(x_test_pr1, y_test)

#Draw the graph
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# Find the best order for model
#POLINOMIAL REGRESSION
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
poly1.score(x_test_pr1, y_test)
# Out:
# 0.8383107898794273

# %%
Rsqu_test = []
order = [1, 2, 3, 4]
lr = LinearRegression()
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train)
    x_test_pr = pr.fit_transform(x_test)    
    lr.fit(x_train_pr, y_train)
   
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
# Best order for regression is 2

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import os 
import seaborn as sns

df = pd.read_csv ('kc_house_data.csv')
print(df)

#check data types
df.dtypes

#convert values
df['bedrooms'] = df['bedrooms'].astype(np.int64)
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

#convert date to int 
df['date']= pd.to_datetime(df['date'])
df['date'] = pd.to_numeric(df['date'])

#Normalize  dataframe
df = (df - df.mean()) / (df.max() - df.min())

#check data types
df.dtypes

#check correlation matrix
df.corr()

#find columns with max correlation
correlation = df.corr(method='pearson')
columns = correlation.nlargest(12, 'price').index
columns

#place the target data price in a separate dataframe y_data . x_data
y_data = df['price']
x_data = df[columns]  
x_data=df.drop('price',axis=1)

#split the series 
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

#import libs
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import sklearn
from scipy import stats
import matplotlib.pyplot as plt



def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

#Run polinomial regression with order = 2
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train)
x_test_pr1=pr1.fit_transform(x_test)
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)
yhat_test = poly1.predict(x_test_pr1)

#Estimate R2 
poly1.score(x_test_pr1, y_test)

#Draw the graph
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# Find the best order for model
#POLINOMIAL REGRESSION

Rsqu_test = []
order = [1, 2, 3]
lr = LinearRegression()
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train)
    x_test_pr = pr.fit_transform(x_test)    
    lr.fit(x_train_pr, y_train)
   
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
# Best order for regression is 2


#Looking for best alpha
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
Ridge(normalize=True)

parameters= [{'alpha': [0.001,0.1,1, 10, 100, 1000,10000,100000,100000],'normalize':[True,False]} ]
Grid2 = GridSearchCV(Ridge(), parameters,cv=4)
Grid2.fit(x_data,y_data)
Grid2.best_estimator_

#Ridge(alpha=1, normalize=True)

pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train)
x_test_pr1=pr1.fit_transform(x_test)
RigeModel = Ridge(alpha=0.001, normalize=True)
RigeModel.fit(x_train_pr1,y_train)
yhat_test = RigeModel.predict(x_test_pr1)

#calcaulate R2
RigeModel.score(x_test_pr1, y_test)

#draw the graph with alpha = 1
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')


#TRY RGBOOST
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingRegressor

HCBR_Model = HistGradientBoostingRegressor()
HCBR_Model.fit(x_train,y_train)
yhat_test = HCBR_Model.predict(x_test)
HCBR_Model.score(x_test, y_test)

#draw the graph with Gradient Boosting Model
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
#draw the graph with Gradient Boosting Model
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
