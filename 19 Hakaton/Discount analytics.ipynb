# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook
pd.set_option('display.max_columns',None)



from pandas.api.types import CategoricalDtype

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly

sns.set(style='whitegrid')
plt.rcParams['figure.figsize']=(15,5)
# %config InlineBackend.figure_format = 'png'
# %matplotlib inline

# %% [markdown]
# Загружаем данные в датафреймы

# %%
df_checks = pd.read_pickle("./df_checks.pkl")

# %%
df_shops = pd.read_pickle("./df_shops.pkl")
df_points = pd.read_pickle("./df_points.pkl")
df_left = pd.read_pickle("./df_left.pkl")

# %%
df_category = pd.read_pickle("./df_category.pkl")
df_checks_with_cat = pd.read_pickle("./df_checks_with_cat.pkl")
df_pivot_table = pd.read_pickle("./df_pivot_table.pkl")
df_week_diff = pd.read_pickle("./df_week_diff.pkl")
df_week_diff_cum = pd.read_pickle("./df_week_diff_cum.pkl")

# %% [markdown]
# Немного Шлифуем данные по чекам

# %%
df_checks['discount'] = df_checks['Price_retail'].sub(df_checks['BasePrice'])
df_checks['discount_percent'] = df_checks['discount'].div(df_checks['Price_retail'])
df_checks['favorite_product'] = df_checks['discount_percent'].apply(lambda x: 1 if 0.19 < x < 0.21  else 0)

# %%
df_bad =  df_shops['id_tt'].loc[df_shops['good_or_bad'] == -1].tolist()
df_good = df_shops['id_tt'].loc[df_shops['good_or_bad'] == 1].tolist()

# %%
df_checks_good = df_checks[df_checks['id_tt_cl'].isin(df_good)]

# %%
df_checks_bad = df_checks[df_checks['id_tt_cl'].isin(df_bad)]

# %%
df_checks_good
# Out:
#                                      CheckUID  id_tt_cl  id_tov_cl  \
# 21878    318729DE-2E99-EC11-9064-005056A7A8DF     11457         52
# 21879    4EB8FF0C-7C99-EC11-9064-005056A7A8DF     11457         52
# 21880    86D50C6F-5299-EC11-9064-005056A7A8DF     11457         52
# 21881    9292B1C9-7899-EC11-9064-005056A7A8DF     11457         52
# 21882    C3A1045D-8699-EC11-9064-005056A7A8DF     11457         52
# ...                                       ...       ...        ...
# 5212503  F21D11A9-FDE0-EC11-9064-005056A7A8DF     14988      24800
# 5212504  8240BFA3-E6E0-EC11-9064-005056A7A8DF     14988      29500
# 5212505  7BA6281E-F1E0-EC11-9064-005056A7A8DF     14988      59900
# 5212506  32FACF0A-07E1-EC11-9064-005056A7A8DF     14988      61400
# 5212507  3DA5DC9C-E8E0-EC11-9064-005056A7A8DF     14988      62800
#
#          Price_retail  Quantity   BasePrice  BaseSum     date_ch   time_ch  \
# 21878      119.090909       1.0  119.090909   119.09  2022-03-01  10:11:04
# 21879      119.090909       1.0  119.090909   119.09  2022-03-01  19:07:06
# 21880      119.090909       1.0  119.090909   119.09  2022-03-01  14:19:08
# 21881      119.090909       1.0  119.090909   119.09  2022-03-01  18:50:40
# 21882      119.090909       1.0  119.090909   119.09  2022-03-01  20:19:32
# ...               ...       ...         ...      ...         ...       ...
# 5212503     38.181818       1.0   38.181818    38.18  2022-05-31  19:08:56
# 5212504    236.666667       2.0  189.166667   378.33  2022-05-31  16:23:54
# 5212505     38.181818       2.0   38.181818    76.36  2022-05-31  17:35:49
# 5212506    177.272727       1.0  177.272727   177.27  2022-05-31  20:16:00
# 5212507    489.090909       1.0  293.454545   293.45  2022-05-31  16:45:22
#
#         order_type  day  year  month  week day_of_week  hour  time  \
# 21878      offline    1  2022      3     9     Tuesday    10    11
# 21879      offline    1  2022      3     9     Tuesday    19     7
# 21880      offline    1  2022      3     9     Tuesday    14    19
# 21881      offline    1  2022      3     9     Tuesday    18    50
# 21882      offline    1  2022      3     9     Tuesday    20    19
# ...            ...  ...   ...    ...   ...         ...   ...   ...
# 5212503    offline   31  2022      5    22     Tuesday    19     8
# 5212504    offline   31  2022      5    22     Tuesday    16    23
# 5212505    offline   31  2022      5    22     Tuesday    17    35
# 5212506    offline   31  2022      5    22     Tuesday    20    16
# 5212507    offline   31  2022      5    22     Tuesday    16    45
#
#            discount  discount_percent  favorite_product
# 21878      0.000000          0.000000                 0
# 21879      0.000000          0.000000                 0
# 21880      0.000000          0.000000                 0
# 21881      0.000000          0.000000                 0
# 21882      0.000000          0.000000                 0
# ...             ...               ...               ...
# 5212503    0.000000          0.000000                 0
# 5212504   47.500000          0.200704                 1
# 5212505    0.000000          0.000000                 0
# 5212506    0.000000          0.000000                 0
# 5212507  195.636364          0.400000                 0
#
# [3334552 rows x 20 columns]

# %%
(df_checks_good[df_checks_good['favorite_product'] == 1].count().CheckUID)/(df_checks_good.count().CheckUID)
# Out:
# 0.04061834993126513

# %%
(df_checks_bad[df_checks_bad['favorite_product'] == 1].count().CheckUID)/(df_checks_bad.count().CheckUID)
# Out:
# 0.040616130072656687
