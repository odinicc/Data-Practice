# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook
pd.set_option('display.max_columns',None)



from pandas.api.types import CategoricalDtype

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly

sns.set(style='whitegrid')
plt.rcParams['figure.figsize']=(15,5)
# %config InlineBackend.figure_format = 'png'
# %matplotlib inline

# %% [markdown]
# Загружаем данные в датафреймы

# %%
df_checks = pd.read_pickle("./df_checks.pkl")

# %%
df_shops = pd.read_pickle("./df_shops.pkl")
df_points = pd.read_pickle("./df_points.pkl")
df_left = pd.read_pickle("./df_left.pkl")

# %%
df_category = pd.read_pickle("./df_category.pkl")
df_checks_with_cat = pd.read_pickle("./df_checks_with_cat.pkl")
df_pivot_table = pd.read_pickle("./df_pivot_table.pkl")
df_week_diff = pd.read_pickle("./df_week_diff.pkl")
df_week_diff_cum = pd.read_pickle("./df_week_diff_cum.pkl")

# %% [markdown]
# Немного Шлифуем данные по чекам

# %%
df_checks_with_cat.drop(('id_tov', ''),axis=1,inplace=True)
df_checks_with_cat.rename(columns = {('name_gr', ''):'name_gr'}, inplace = True)

# %%
df_checks_with_cat.head()
# Out:
#    id_tt_cl  id_tov_cl  Quantity     date_ch  week  BaseSum  \
# 0     10864         52       1.0  2022-03-01     9   119.09
# 1     10864         52       1.0  2022-03-01     9   119.09
# 2     10864         52       1.0  2022-03-01     9   119.09
# 3     10864         52       1.0  2022-03-01     9   119.09
# 4     10864         52       1.0  2022-03-01     9   119.09
#
#               name_gr
# 0  Молочная Продукция
# 1  Молочная Продукция
# 2  Молочная Продукция
# 3  Молочная Продукция
# 4  Молочная Продукция

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df_week_diff, cmap='vlag')
plt.title('Недельное изменение выручки в магазинах камулятивно');

# %%
df_category_pivot_sum = df_checks_with_cat.pivot_table(columns=['name_gr'],index=['id_tt_cl'],values = ['BaseSum'],aggfunc= 'sum',fill_value=0).reset_index()

# %% [markdown]
# Исправляем кривое форматирование пивот таблицы

# %%
df_category_pivot_sum2 = pd.concat([df_category_pivot_sum['id_tt_cl'].to_frame(),df_category_pivot_sum.loc[:,'BaseSum']], axis=1)

# %% [markdown]
# Добавляем по каждому магазину суммарное количество проданных итемов -- df_category_pivot_sum2

# %%
df_category_pivot_sum2['overal_sum'] = df_category_pivot_sum2.drop('id_tt_cl',axis=1).sum(axis=1)

# %% [markdown]
# Добавляем по каждому магазину количество проданных итемов в процентах по каждой категории -- df_category_pivot_sum3

# %%
df_category_pivot_sum3 = df_category_pivot_sum2.copy()

# %%
for column in df_category_pivot_sum3.drop(['id_tt_cl','overal_sum'],axis=1):
    df_category_pivot_sum3[column] = df_category_pivot_sum3[column].div(df_category_pivot_sum3['overal_sum']/100)

# %%
del df_category_pivot_sum3['overal_sum']

# %% [markdown]
# Выбираем хорошие и плохие магазины

# %%
df_average =  df_shops['id_tt'].loc[df_shops['good_or_bad'] == 0].tolist()
df_bad =  df_shops['id_tt'].loc[df_shops['good_or_bad'] == -1].tolist()
df_good = df_shops['id_tt'].loc[df_shops['good_or_bad'] == 1].tolist()

# %%
df_category_good = df_category_pivot_sum3.loc[df_category_pivot_sum3['id_tt_cl'].isin(df_good)]
df_category_bad = df_category_pivot_sum3.loc[df_category_pivot_sum3['id_tt_cl'].isin(df_bad)]
df_category_average = df_category_pivot_sum3.loc[df_category_pivot_sum3['id_tt_cl'].isin(df_average)]

# %%
df_category_good_mn = df_category_good.mean(axis=0).to_frame(name="good")
df_category_bad_mn = df_category_bad.mean(axis=0).to_frame(name="average")
df_category_average_mn = df_category_average.mean(axis=0).to_frame(name="bad")

# %%
df_category_diff =  pd.concat([df_category_good_mn,df_category_average_mn, df_category_bad_mn], ignore_index=False, axis=1)

# %%
df_category_diff = df_category_diff.drop(index='id_tt_cl')

# %%
df_category_diff
# Out:
#                                                      good           bad  \
# Айс ВкусВилл                                     0.062433  2.201470e-01
# Алкоголь                                         1.574279  1.439297e+00
# Архив                                            0.255205  2.269192e-01
# Бакалея                                          4.190952  4.014249e+00
# Бытовая Химия                                    0.271231  2.543711e-01
# ВВ Праздник                                      0.002509  5.541481e-04
# Выбор покупателя                                 0.000297  9.889826e-04
# Гастрополка                                      0.001343  1.114587e-04
# ДаркКитчен                                       0.000000  0.000000e+00
# Детские товары                                   0.508024  4.457539e-01
# Детское питание                                  0.523723  4.975853e-01
# Довериум                                         0.000000  1.815700e-06
# Замороженные десерты                             1.885809  1.679328e+00
# Замороженные продукты                            3.176295  2.769720e+00
# Интернет-магазин                                 0.000000  2.399289e-04
# Кафе                                             0.000811  1.802110e+00
# Консервация                                      1.717999  1.679000e+00
# Косметика                                        0.685165  6.222601e-01
# Кулинария                                       14.305858  1.548455e+01
# Кулинарный конструктор                           0.000000  0.000000e+00
# Личная гигиена и уход                            0.761728  7.533734e-01
# Медицинские товары                               0.313094  2.772167e-01
# Микромаркет                                      0.000115  1.189928e-03
# Мировые бренды                                   0.045689  5.443551e-02
# Молочная Продукция                              13.849597  1.215294e+01
# Мясная Витрина ВВ                                0.000000  1.722242e-04
# Мясные деликатесы. Колбасы                       4.438248  4.066449e+00
# Мясо. Птица. П/ф охл. Яйца                       6.643737  6.336644e+00
# Напитки                                          3.305842  3.716013e+00
# Овощи. Фрукты. Грибы. Зелень                    13.331748  1.472747e+01
# Отдел без упаковки                               0.001300  3.674515e-02
# Пекарня                                          0.000037  6.846949e-05
# Подписки на товары и услуги                      0.071126  7.567257e-02
# Проекты нон-фуд                                  0.013706  5.102904e-02
# Пространство ВкусВилл                            0.042097  2.017225e-01
# Прочее                                           0.016052  2.592594e-02
# Рационы                                          0.000000  9.963381e-08
# Региональная полка                               0.000277  1.236758e-03
# Рестораны                                        0.000116  7.839568e-05
# Рыба. Морепродукты                               5.177689  5.148278e+00
# Рыбная витрина                                   0.000000  3.281038e-04
# Сладости, кондитерские изделия                   6.592969  6.031697e+00
# Сухофрукты. Сушеные овощи, грибы, ягоды. Орехи   1.344750  1.345653e+00
# Сыры                                             4.058233  3.780966e+00
# Товары для Еком контрагентов                     0.000178  3.139306e-03
# Товары для дома                                  0.711788  7.191214e-01
# Товары для животных                              0.289791  2.701042e-01
# Торты, пирожные, десерты                         5.779473  5.196900e+00
# ФС Общепит                                       0.000000  5.793500e-05
# Фрешбар                                          0.000023  4.632284e-04
# Хлеб                                             4.048610  3.887551e+00
# Чай и кофе. Проекты                              0.000000  4.108812e-05
# Электронная Коммерция                            0.000055  1.346903e-04
#
#                                                      average
# Айс ВкусВилл                                    3.092176e-01
# Алкоголь                                        1.314509e+00
# Архив                                           2.127401e-01
# Бакалея                                         4.010077e+00
# Бытовая Химия                                   2.694820e-01
# ВВ Праздник                                     1.085012e-03
# Выбор покупателя                                2.426029e-04
# Гастрополка                                     1.849685e-05
# ДаркКитчен                                      2.406057e-05
# Детские товары                                  4.438603e-01
# Детское питание                                 4.507002e-01
# Довериум                                        3.642453e-07
# Замороженные десерты                            1.579724e+00
# Замороженные продукты                           2.621981e+00
# Интернет-магазин                                2.473926e-05
# Кафе                                            1.437856e+00
# Консервация                                     1.679698e+00
# Косметика                                       6.342623e-01
# Кулинария                                       1.575502e+01
# Кулинарный конструктор                          5.323784e-06
# Личная гигиена и уход                           7.966245e-01
# Медицинские товары                              3.063078e-01
# Микромаркет                                     5.237351e-03
# Мировые бренды                                  1.569283e-01
# Молочная Продукция                              1.222768e+01
# Мясная Витрина ВВ                               0.000000e+00
# Мясные деликатесы. Колбасы                      3.985501e+00
# Мясо. Птица. П/ф охл. Яйца                      6.647496e+00
# Напитки                                         3.490871e+00
# Овощи. Фрукты. Грибы. Зелень                    1.434131e+01
# Отдел без упаковки                              4.263611e-02
# Пекарня                                         6.246510e-05
# Подписки на товары и услуги                     7.415739e-02
# Проекты нон-фуд                                 4.504770e-02
# Пространство ВкусВилл                           1.850846e-01
# Прочее                                          2.281406e-02
# Рационы                                         0.000000e+00
# Региональная полка                              1.395849e-03
# Рестораны                                       3.451754e-04
# Рыба. Морепродукты                              5.040901e+00
# Рыбная витрина                                  3.150654e-01
# Сладости, кондитерские изделия                  6.034160e+00
# Сухофрукты. Сушеные овощи, грибы, ягоды. Орехи  1.467277e+00
# Сыры                                            3.897333e+00
# Товары для Еком контрагентов                    2.947562e-03
# Товары для дома                                 7.305700e-01
# Товары для животных                             2.981228e-01
# Торты, пирожные, десерты                        5.317555e+00
# ФС Общепит                                      6.157442e-05
# Фрешбар                                         2.940554e-04
# Хлеб                                            3.845482e+00
# Чай и кофе. Проекты                             1.290188e-04
# Электронная Коммерция                           6.920652e-05

# %%
df_category_diff.to_excel("categories_in_good_and_bad_shops_by_sum.xlsx")

# %%
df_category_diff.to_pickle("./categories_in_good_and_bad_shops_by_sum.pkl")
