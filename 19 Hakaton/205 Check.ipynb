# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")
import matplotlib.pyplot as plt

# %%
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 20))

# %%
# Load the example car crash dataset
crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# %%
del crashes['abbrev']

# %%
crashes_small = crashes.iloc[[40,34,48,3,17,26]]

# %%
crashes_small = crashes_small.transpose()

# %%
crashes_small
# Out:
#                       32       45       23       3        16       12
# total             12.300   13.600    9.600   22.400   17.800   15.300
# speeding           3.936    4.080    2.208    4.032    4.806    5.508
# alcohol            3.567    4.080    2.784    5.824    4.272    4.437
# not_distracted    10.824   13.056    8.448   21.056   13.706   13.005
# no_previous        9.840   12.920    8.448   21.280   15.130   14.994
# ins_premium     1234.310  716.200  777.180  827.340  780.450  641.960
# ins_losses       150.010  109.610  133.350  142.390  133.800   82.750

# %%
fig, ax1 = pyplot.subplots(figsize=(10, 10))
# Plot the total crashes
sns.set_color_codes("pastel")
sns.set(rc={'figure.figsize':(11,18.27)})
sns.barplot( crashes_small.index, crashes_small[[32,45]], data=crashes_small,
            label="Total", color="b", ax=ax1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ivan\Dropbox\vkusvill.ru\Check.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ivan/Dropbox/vkusvill.ru/Check.ipynb#ch0000015?line=0'>1</a> fig, ax1 = pyplot.subplots(figsize=(10, 10))
#       <a href='vscode-notebook-cell:/c%3A/Users/ivan/Dropbox/vkusvill.ru/Check.ipynb#ch0000015?line=1'>2</a> # Plot the total crashes
#       <a href='vscode-notebook-cell:/c%3A/Users/ivan/Dropbox/vkusvill.ru/Check.ipynb#ch0000015?line=2'>3</a> sns.set_color_codes("pastel")
#
# NameError: name 'pyplot' is not defined

# %%
crashes_small.plot(kind="barh",figsize=(10,30))
# Out:
# <AxesSubplot:>
