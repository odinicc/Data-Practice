# %%
import os
import numpy as np 
import pandas as pd 
from itertools import islice, cycle
from more_itertools import pairwise
import scipy
from scipy.spatial import distance

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
v1 = [4, 2]
v2 = [2, -2]

# %%
data = np.array([v1,v2])
origin = np.array([[0, 0], [0, 0]])

# %%
plt.quiver(*origin, data[:, 0], data[:, 1], color=['black', 'red', 'green'], scale=15)

# %%
np.dot(v1,v2)
# Out:
# 4

# %%
scipy.spatial.distance.euclidean(v1,v2)
# Out:
# 4.47213595499958

# %%
scipy.spatial.distance.cosine(v1, v2, w=None)
# Out:
# 0.683772233983162

# %%
#App_Recomendation
app_s = [1,0,0,0,1,0]
app_r = [0,1,0,1,0,0]
app_l = [0,0,1,0,0,1]
app_u = [1,0,0,0,1,1]

# %%
from IPython.display import Image
Image("./Toy_Content_based_Filtering.png")

# %%
mas = ['s','r','l','u']
for m1 in mas:
    for m2 in mas:
        if m1 != m2 and m1 < m2 :
            vec1 = globals()['app_' + m1]
            vec2 = globals()['app_' + m2]
            print(m1,  vec1 ,' - ' , m2, vec2 ,' - ',np.dot(vec1,vec2))
# Out:
# s [1, 0, 0, 0, 1, 0]  -  u [1, 0, 0, 0, 1, 1]  -  2
# r [0, 1, 0, 1, 0, 0]  -  s [1, 0, 0, 0, 1, 0]  -  0
# r [0, 1, 0, 1, 0, 0]  -  u [1, 0, 0, 0, 1, 1]  -  0
# l [0, 0, 1, 0, 0, 1]  -  s [1, 0, 0, 0, 1, 0]  -  0
# l [0, 0, 1, 0, 0, 1]  -  r [0, 1, 0, 1, 0, 0]  -  0
# l [0, 0, 1, 0, 0, 1]  -  u [1, 0, 0, 0, 1, 1]  -  1
