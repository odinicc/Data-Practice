# %%
from urllib.request import urlopen
import json
import pandas as pd

# %%
df = pd.read_json('https://data.cityofchicago.org/resource/9xs2-f89t.json')

# %%
list(df)
# Out:
# ['school_id',
#  'name_of_school',
#  'elementary_or_high_school',
#  'street_address',
#  'city',
#  'state',
#  'zip_code',
#  'phone_number',
#  'link_',
#  'network_manager',
#  'collaborative_name',
#  'adequate_yearly_progress_made_',
#  'track_schedule',
#  'cps_performance_policy_status',
#  'cps_performance_policy_level',
#  'healthy_schools_certified_',
#  'safety_icon_',
#  'safety_score',
#  'family_involvement_icon',
#  'family_involvement_score',
#  'environment_icon_',
#  'environment_score',
#  'instruction_icon_',
#  'instruction_score',
#  'leaders_icon_',
#  'leaders_score_',
#  'teachers_icon_',
#  'teachers_score',
#  'parent_engagement_icon_',
#  'parent_engagement_score',
#  'parent_environment_icon',
#  'parent_environment_score',
#  'average_student_attendance',
#  'rate_of_misconducts_per_100_students_',
#  'average_teacher_attendance',
#  'individualized_education_program_compliance_rate_',
#  'pk_2_literacy',
#  'pk_2_math_',
#  'gr3_5_grade_level_math',
#  'gr3_5_grade_level_read_',
#  'gr3_5_keep_pace_read_',
#  'gr3_5_keep_pace_math',
#  'gr6_8_grade_level_math',
#  'gr6_8_grade_level_read',
#  'gr6_8_keep_pace_math',
#  'gr6_8_keep_pace_read',
#  'gr_8_explore_math',
#  'gr_8_explore_read',
#  'isat_exceeding_math_',
#  'isat_exceeding_reading_',
#  'isat_value_add_math',
#  'isat_value_add_read',
#  'isat_value_add_color_math',
#  'isat_value_add_color_read',
#  'students_taking_algebra',
#  'students_passing_algebra',
#  '_th_grade_explore_2009_',
#  '_th_grade_explore_2010_',
#  '_th_grade_plan_2009_',
#  '_th_grade_plan_2010_',
#  'net_change_explore_and_plan',
#  '_th_grade_average_act_2011_',
#  'net_change_plan_and_act',
#  'college_eligibility_',
#  'graduation_rate_',
#  'college_enrollment_rate',
#  'college_enrollment_number_of_students_',
#  'general_services_route_',
#  'freshman_on_track_rate',
#  'rcdts_code',
#  'x_coordinate',
#  'y_coordinate',
#  'latitude',
#  'longitude',
#  'community_area_number',
#  'community_area_name',
#  'ward',
#  'police_district',
#  'location',
#  ':@computed_region_rpca_8um6',
#  ':@computed_region_vrxf_vc4k',
#  ':@computed_region_6mkv_f3dw',
#  ':@computed_region_bdys_3d7i',
#  ':@computed_region_43wa_7qmu',
#  ':@computed_region_awaf_s7ux']

# %%
df.drop(columns=[ ':@computed_region_rpca_8um6',
 ':@computed_region_vrxf_vc4k',
 ':@computed_region_6mkv_f3dw',
 ':@computed_region_bdys_3d7i',
 ':@computed_region_43wa_7qmu',
 ':@computed_region_awaf_s7ux'], axis=1, inplace=True)

# %%
list(df)
# Out:
# ['school_id',
#  'name_of_school',
#  'elementary_or_high_school',
#  'street_address',
#  'city',
#  'state',
#  'zip_code',
#  'phone_number',
#  'link_',
#  'network_manager',
#  'collaborative_name',
#  'adequate_yearly_progress_made_',
#  'track_schedule',
#  'cps_performance_policy_status',
#  'cps_performance_policy_level',
#  'healthy_schools_certified_',
#  'safety_icon_',
#  'safety_score',
#  'family_involvement_icon',
#  'family_involvement_score',
#  'environment_icon_',
#  'environment_score',
#  'instruction_icon_',
#  'instruction_score',
#  'leaders_icon_',
#  'leaders_score_',
#  'teachers_icon_',
#  'teachers_score',
#  'parent_engagement_icon_',
#  'parent_engagement_score',
#  'parent_environment_icon',
#  'parent_environment_score',
#  'average_student_attendance',
#  'rate_of_misconducts_per_100_students_',
#  'average_teacher_attendance',
#  'individualized_education_program_compliance_rate_',
#  'pk_2_literacy',
#  'pk_2_math_',
#  'gr3_5_grade_level_math',
#  'gr3_5_grade_level_read_',
#  'gr3_5_keep_pace_read_',
#  'gr3_5_keep_pace_math',
#  'gr6_8_grade_level_math',
#  'gr6_8_grade_level_read',
#  'gr6_8_keep_pace_math',
#  'gr6_8_keep_pace_read',
#  'gr_8_explore_math',
#  'gr_8_explore_read',
#  'isat_exceeding_math_',
#  'isat_exceeding_reading_',
#  'isat_value_add_math',
#  'isat_value_add_read',
#  'isat_value_add_color_math',
#  'isat_value_add_color_read',
#  'students_taking_algebra',
#  'students_passing_algebra',
#  '_th_grade_explore_2009_',
#  '_th_grade_explore_2010_',
#  '_th_grade_plan_2009_',
#  '_th_grade_plan_2010_',
#  'net_change_explore_and_plan',
#  '_th_grade_average_act_2011_',
#  'net_change_plan_and_act',
#  'college_eligibility_',
#  'graduation_rate_',
#  'college_enrollment_rate',
#  'college_enrollment_number_of_students_',
#  'general_services_route_',
#  'freshman_on_track_rate',
#  'rcdts_code',
#  'x_coordinate',
#  'y_coordinate',
#  'latitude',
#  'longitude',
#  'community_area_number',
#  'community_area_name',
#  'ward',
#  'police_district',
#  'location']

# %%
import psycopg2
import IPython
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2

# %%
# %load_ext sql
# %sql postgresql+psycopg2://postgres:5677@/IBM_SQL

# %%
# %%sql
# SELECT * FROM information_schema.tables
# Out:
#  * postgresql+psycopg2://postgres:***@/IBM_SQL
# 198 rows affected.
# [('IBM_SQL', 'public', 'job_history', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'public', 'locations', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'public', 'employees', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'public', 'departments', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'public', 'jobs', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'public', 'petrescue', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_statistic', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_type', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'public', 'book', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_policy', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_authid', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'public', 'international_student_test_scores', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_shadow', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_settings', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_hba_file_rules', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_file_settings', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_config', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'public', 'chicago_socioeconomic_data', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_user_mapping', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_replication_origin_status', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_subscription', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_user_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_xact_user_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_attribute', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_proc', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_class', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_attrdef', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_constraint', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_statio_all_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_statio_sys_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_statio_user_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_all_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_inherits', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_index', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_operator', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_opfamily', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_opclass', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_am', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_amop', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_amproc', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_language', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_largeobject_metadata', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_aggregate', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_statistic_ext', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_rewrite', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_trigger', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_event_trigger', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_description', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_cast', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_enum', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_namespace', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_conversion', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_depend', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_database', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_db_role_setting', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_tablespace', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_pltemplate', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_auth_members', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_shdepend', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_shdescription', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_ts_config', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_ts_config_map', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_ts_dict', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_ts_parser', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_ts_template', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_extension', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_foreign_data_wrapper', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_foreign_server', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_foreign_table', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_replication_origin', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_default_acl', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_init_privs', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_seclabel', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_shseclabel', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_collation', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_partitioned_table', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_range', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_transform', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_sequence', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_publication', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_publication_rel', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_subscription_rel', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_roles', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_locks', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_group', 'VIEW', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_user', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_policies', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_rules', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_views', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_matviews', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_sequences', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stats', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_publication_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_cursors', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_available_extensions', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_available_extension_versions', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_prepared_xacts', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_prepared_statements', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_seclabels', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_timezone_abbrevs', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_timezone_names', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_all_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_xact_all_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_sys_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_xact_sys_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_sys_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_user_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_statio_all_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_statio_sys_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_statio_user_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_statio_all_sequences', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_statio_sys_sequences', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_statio_user_sequences', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_activity', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_replication', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_wal_receiver', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_subscription', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_ssl', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_replication_slots', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_database', 'VIEW', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_database_conflicts', 'VIEW', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_user_functions', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_xact_user_functions', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_archiver', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_bgwriter', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_stat_progress_vacuum', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_user_mappings', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'pg_catalog', 'pg_largeobject', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'information_schema_catalog_name', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'attributes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'applicable_roles', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'administrable_role_authorizations', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'check_constraint_routine_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'character_sets', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'check_constraints', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'collations', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'collation_character_set_applicability', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'column_domain_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'column_privileges', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'routine_privileges', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'column_udt_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'columns', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'constraint_column_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'role_routine_grants', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'constraint_table_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'domain_constraints', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'domain_udt_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'routines', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'domains', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'enabled_roles', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'sql_parts', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'key_column_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'schemata', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'parameters', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'referential_constraints', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'sql_languages', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'role_column_grants', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'sequences', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'sql_features', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'sql_implementation_info', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'sql_packages', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'sql_sizing', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'sql_sizing_profiles', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'view_routine_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'table_constraints', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'table_privileges', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'foreign_table_options', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'role_table_grants', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'view_table_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'transforms', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'triggered_update_columns', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'foreign_data_wrappers', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'triggers', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'views', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'udt_privileges', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'role_udt_grants', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'usage_privileges', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'data_type_privileges', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'role_usage_grants', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'user_defined_types', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', '_pg_foreign_servers', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'view_column_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'element_types', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', '_pg_foreign_table_columns', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'column_options', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', '_pg_foreign_data_wrappers', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'foreign_server_options', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'foreign_data_wrapper_options', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'foreign_servers', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', '_pg_foreign_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'user_mapping_options', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'foreign_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', '_pg_user_mappings', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'information_schema', 'user_mappings', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('IBM_SQL', 'public', 'chicago_public_schools', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)]
