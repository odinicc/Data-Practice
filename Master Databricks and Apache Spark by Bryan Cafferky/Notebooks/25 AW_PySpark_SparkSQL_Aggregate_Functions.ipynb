# %% [markdown]
# ## AdventureWorks EDA Using Spark SQL aggregate functions from Python
#
# ![Spark Logo](http://spark-mooc.github.io/web-assets/images/ta_Spark-logo-small.png)
#
# More examples are available on the Spark website: http://spark.apache.org/examples.html
#
# PySpark API documentation: http://spark.apache.org/docs/latest/api/python/

# %% [markdown]
# ## Author: Bryan Cafferky Copyright 08/20/2021

# %% [markdown]
# ### Warning!!!
#
# #### To run this code, you need to have uploaded the files and created the database tables - see Lesson 9 - Creating the SQL Tables on Databricks.  Link in video description to that video.

# %% [markdown]
# ## Using Spark SQL from Python

# %% [markdown]
# #### Dataframe naming prefix convention:
# ##### 1st character is s for Spark DF
# ##### 2nd character is p for Python
# ##### 3rd and 4th character is df for dataframe
# ##### 5th = _ separator
# ##### rest is a meaningful name
#
# ##### spdf_salessummary = a Spark Python dataframe containing sales summary information.

# %%
spark.sql('use awproject')
spdf_salesinfo = spark.sql('select * from factinternetsales').dropna()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(spdf_salesinfo.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ProductKey</th><th>OrderDateKey</th><th>DueDateKey</th><th>ShipDateKey</th><th>CustomerKey</th><th>PromotionKey</th><th>CurrencyKey</th><th>SalesTerritoryKey</th><th>SalesOrderNumber</th><th>SalesOrderLineNumber</th><th>RevisionNumber</th><th>OrderQuantity</th><th>UnitPrice</th><th>ExtendedAmount</th><th>UnitPriceDiscountPct</th><th>DiscountAmount</th><th>ProductStandardCost</th><th>TotalProductCost</th><th>SalesAmount</th><th>TaxAmt</th><th>Freight</th><th>CarrierTrackingNumber</th><th>CustomerPONumber</th><th>OrderDate</th><th>DueDate</th><th>ShipDate</th></tr></thead><tbody><tr><td>310</td><td>20101229</td><td>20110110</td><td>20110105</td><td>21768</td><td>1</td><td>19</td><td>6</td><td>SO43697</td><td>1</td><td>1</td><td>1</td><td>3578.27</td><td>3578.27</td><td>0</td><td>0</td><td>2171.2942</td><td>2171.2942</td><td>3578.27</td><td>286.2616</td><td>89.4568</td><td>NULL</td><td>NULL</td><td>2010-12-29 00:00:00.000</td><td>2011-01-10 00:00:00.000</td><td>2011-01-05 00:00:00.000</td></tr><tr><td>346</td><td>20101229</td><td>20110110</td><td>20110105</td><td>28389</td><td>1</td><td>39</td><td>7</td><td>SO43698</td><td>1</td><td>1</td><td>1</td><td>3399.99</td><td>3399.99</td><td>0</td><td>0</td><td>1912.1544</td><td>1912.1544</td><td>3399.99</td><td>271.9992</td><td>84.9998</td><td>NULL</td><td>NULL</td><td>2010-12-29 00:00:00.000</td><td>2011-01-10 00:00:00.000</td><td>2011-01-05 00:00:00.000</td></tr><tr><td>346</td><td>20101229</td><td>20110110</td><td>20110105</td><td>25863</td><td>1</td><td>100</td><td>1</td><td>SO43699</td><td>1</td><td>1</td><td>1</td><td>3399.99</td><td>3399.99</td><td>0</td><td>0</td><td>1912.1544</td><td>1912.1544</td><td>3399.99</td><td>271.9992</td><td>84.9998</td><td>NULL</td><td>NULL</td><td>2010-12-29 00:00:00.000</td><td>2011-01-10 00:00:00.000</td><td>2011-01-05 00:00:00.000</td></tr><tr><td>336</td><td>20101229</td><td>20110110</td><td>20110105</td><td>14501</td><td>1</td><td>100</td><td>4</td><td>SO43700</td><td>1</td><td>1</td><td>1</td><td>699.0982</td><td>699.0982</td><td>0</td><td>0</td><td>413.1463</td><td>413.1463</td><td>699.0982</td><td>55.9279</td><td>17.4775</td><td>NULL</td><td>NULL</td><td>2010-12-29 00:00:00.000</td><td>2011-01-10 00:00:00.000</td><td>2011-01-05 00:00:00.000</td></tr><tr><td>346</td><td>20101229</td><td>20110110</td><td>20110105</td><td>11003</td><td>1</td><td>6</td><td>9</td><td>SO43701</td><td>1</td><td>1</td><td>1</td><td>3399.99</td><td>3399.99</td><td>0</td><td>0</td><td>1912.1544</td><td>1912.1544</td><td>3399.99</td><td>271.9992</td><td>84.9998</td><td>NULL</td><td>NULL</td><td>2010-12-29 00:00:00.000</td><td>2011-01-10 00:00:00.000</td><td>2011-01-05 00:00:00.000</td></tr></tbody></table></div>

# %% [markdown]
# #### Using SQL Aggregate Functions via agg()
# https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.GroupedData.agg.html

# %% [markdown]
# ### More on using SQL Aggregate Functions
# https://sparkbyexamples.com/spark/spark-sql-aggregate-functions/

# %% [markdown]
# ### Just using SQL directly...

# %%
# %sql

SELECT avg(SalesAmount) as avg_sales, 
       stddev(SalesAmount) as std_sales, 
       min(SalesAmount) as min_sales, 
       max(SalesAmount) as max_sales, 
       approx_count_distinct(ProductKey) as count_productkey, 
       approx_count_distinct(CustomerKey) as count_customerkey
FROM factinternetsales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg_sales</th><th>std_sales</th><th>min_sales</th><th>max_sales</th><th>count_productkey</th><th>count_customerkey</th></tr></thead><tbody><tr><td>486.0869105053777</td><td>928.489891980807</td><td>2.29</td><td>3578.27</td><td>161</td><td>17004</td></tr></tbody></table></div>

# %%
spdf_salesagg = spark.sql('''
SELECT avg(SalesAmount) as avg_sales, 
       stddev(SalesAmount) as std_sales, 
       min(SalesAmount) as min_sales, 
       max(SalesAmount) as max_sales, 
       approx_count_distinct(ProductKey) as count_productkey, 
       approx_count_distinct(CustomerKey) as count_customerkey
FROM factinternetsales''')

display(spdf_salesagg)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg_sales</th><th>std_sales</th><th>min_sales</th><th>max_sales</th><th>count_productkey</th><th>count_customerkey</th></tr></thead><tbody><tr><td>486.0869105053777</td><td>928.489891980807</td><td>2.29</td><td>3578.27</td><td>161</td><td>17004</td></tr></tbody></table></div>

# %% [markdown]
# ### Look mom, just Python...

# %%
# import some more functions
from pyspark.sql.functions import countDistinct
from pyspark.sql.functions import avg
from pyspark.sql.functions import max, min
from pyspark.sql.functions import stddev

# Perform aggregations on the DataFrame
spdf_agg = spdf_salesinfo.agg(
    avg(spdf_salesinfo.SalesAmount).alias("avg_sales"), 
    stddev("SalesAmount").alias("stddev_sales"),
    min(spdf_salesinfo.SalesAmount).alias("min_sales"),
    max(spdf_salesinfo.SalesAmount).alias("max_sales"),
    countDistinct(spdf_salesinfo.ProductKey).alias("distinct_products"), 
    countDistinct(spdf_salesinfo['CustomerKey']).alias('distinct_customers')
)

# Convert the results to Pandas DataFrame
spdf_agg.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>avg_sales</th>
#       <th>stddev_sales</th>
#       <th>min_sales</th>
#       <th>max_sales</th>
#       <th>distinct_products</th>
#       <th>distinct_customers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>486.086911</td>
#       <td>928.489892</td>
#       <td>2.29</td>
#       <td>3578.27</td>
#       <td>158</td>
#       <td>18484</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
type(spdf_agg)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: pyspark.sql.dataframe.DataFrame</div>

# %%
import pyspark.sql.functions

spdf_salesinfo.groupBy("ProductKey").avg("SalesAmount").toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ProductKey</th>
#       <th>avg(SalesAmount)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>463</td>
#       <td>24.49</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>471</td>
#       <td>63.50</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>540</td>
#       <td>32.60</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>580</td>
#       <td>1700.99</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>588</td>
#       <td>769.49</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>153</th>
#       <td>535</td>
#       <td>24.99</td>
#     </tr>
#     <tr>
#       <th>154</th>
#       <td>562</td>
#       <td>2384.07</td>
#     </tr>
#     <tr>
#       <th>155</th>
#       <td>475</td>
#       <td>69.99</td>
#     </tr>
#     <tr>
#       <th>156</th>
#       <td>483</td>
#       <td>120.00</td>
#     </tr>
#     <tr>
#       <th>157</th>
#       <td>584</td>
#       <td>539.99</td>
#     </tr>
#   </tbody>
# </table>
# <p>158 rows × 2 columns</p>
# </div>

# %%
#  See https://sparkbyexamples.com/spark/using-groupby-on-dataframe/

import pyspark.sql.functions

# Notice, groupBy() before the agg() functions.
spdf_salesinfo.groupBy("PromotionKey").agg(
    avg("SalesAmount").alias("avg_sales"), 
    stddev("SalesAmount").alias("stddev_sales"),
    min(spdf_salesinfo.SalesAmount).alias("min_sales"),
    max(spdf_salesinfo.SalesAmount).alias("max_sales"),
    countDistinct(spdf_salesinfo.ProductKey).alias("distinct_products"), 
    countDistinct(spdf_salesinfo['CustomerKey']).alias('distinct_customers')
).toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PromotionKey</th>
#       <th>avg_sales</th>
#       <th>stddev_sales</th>
#       <th>min_sales</th>
#       <th>max_sales</th>
#       <th>distinct_products</th>
#       <th>distinct_customers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>468.824267</td>
#       <td>919.211592</td>
#       <td>2.29</td>
#       <td>3578.27</td>
#       <td>156</td>
#       <td>18405</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>13</td>
#       <td>742.350000</td>
#       <td>0.000000</td>
#       <td>742.35</td>
#       <td>742.35</td>
#       <td>9</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14</td>
#       <td>2384.070000</td>
#       <td>0.000000</td>
#       <td>2384.07</td>
#       <td>2384.07</td>
#       <td>4</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>946.756482</td>
#       <td>1050.885142</td>
#       <td>2.29</td>
#       <td>2443.35</td>
#       <td>19</td>
#       <td>1990</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Modifed example from https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.GroupedData.agg.html

from pyspark.sql import functions as F

lpls_salesagg = spdf_salesinfo.agg(F.min(spdf_salesinfo.SalesAmount), F.max(spdf_salesinfo.SalesAmount)).collect()
lpls_salesagg
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: [Row(min(SalesAmount)=2.29, max(SalesAmount)=3578.27)]</div>

# %%
type(lpls_salesagg)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: list</div>

# %%
from pyspark.sql import functions as F

lpdf_salesagg = spdf_salesinfo.agg(F.min(spdf_salesinfo.SalesAmount), F.max(spdf_salesinfo.SalesAmount)).toPandas()
lpdf_salesagg
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>min(SalesAmount)</th>
#       <th>max(SalesAmount)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2.29</td>
#       <td>3578.27</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from pyspark.sql.functions import col

spdf_salesinfo.groupBy("SalesTerritoryKey").agg(
                   avg("SalesAmount"), 
                   stddev("SalesAmount"), 
                   min("SalesAmount"), 
                   max("SalesAmount"), 
                   countDistinct("ProductKey"), countDistinct("CustomerKey"),
                   countDistinct("ProductKey", "CustomerKey")).where(col("count(ProductKey)") > 1).toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SalesTerritoryKey</th>
#       <th>avg(SalesAmount)</th>
#       <th>stddev_samp(SalesAmount)</th>
#       <th>min(SalesAmount)</th>
#       <th>max(SalesAmount)</th>
#       <th>count(ProductKey)</th>
#       <th>count(CustomerKey)</th>
#       <th>count(ProductKey, CustomerKey)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>405.856394</td>
#       <td>860.822489</td>
#       <td>2.29</td>
#       <td>3578.2700</td>
#       <td>157</td>
#       <td>3341</td>
#       <td>8969</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6</td>
#       <td>259.559693</td>
#       <td>722.628771</td>
#       <td>2.29</td>
#       <td>3578.2700</td>
#       <td>151</td>
#       <td>1571</td>
#       <td>6653</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>150.041480</td>
#       <td>467.091251</td>
#       <td>2.29</td>
#       <td>2071.4196</td>
#       <td>15</td>
#       <td>8</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5</td>
#       <td>313.816656</td>
#       <td>700.421726</td>
#       <td>2.29</td>
#       <td>2384.0700</td>
#       <td>25</td>
#       <td>12</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>9</td>
#       <td>678.980936</td>
#       <td>1074.124424</td>
#       <td>2.29</td>
#       <td>3578.2700</td>
#       <td>158</td>
#       <td>3591</td>
#       <td>13208</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>466.216944</td>
#       <td>917.382067</td>
#       <td>2.29</td>
#       <td>3578.2700</td>
#       <td>158</td>
#       <td>4450</td>
#       <td>12250</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>8</td>
#       <td>514.544416</td>
#       <td>918.170934</td>
#       <td>2.29</td>
#       <td>3578.2700</td>
#       <td>158</td>
#       <td>1780</td>
#       <td>5584</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>475.713874</td>
#       <td>887.339536</td>
#       <td>2.29</td>
#       <td>3578.2700</td>
#       <td>155</td>
#       <td>1810</td>
#       <td>5461</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>10</td>
#       <td>491.125429</td>
#       <td>900.427387</td>
#       <td>2.29</td>
#       <td>3578.2700</td>
#       <td>155</td>
#       <td>1913</td>
#       <td>6840</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2</td>
#       <td>241.943267</td>
#       <td>644.381638</td>
#       <td>2.29</td>
#       <td>2294.9900</td>
#       <td>17</td>
#       <td>8</td>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table>
# </div>
