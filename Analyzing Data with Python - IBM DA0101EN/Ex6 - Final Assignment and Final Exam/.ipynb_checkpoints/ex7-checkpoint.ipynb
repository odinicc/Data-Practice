# %%
import pandas as pd
import numpy as np

df = pd.read_csv ('kc_house_data.csv')
print(df)

#check data types
df.dtypes
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
#convert values
df['bedrooms'] = df['bedrooms'].astype(np.int64)
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

# %%
df['dateint'] = pd.to_numeric(df['date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "20141013T000000"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6384/2793312676.py in <module>
# ----> 1 df['dateint'] = pd.to_numeric(df['date'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "20141013T000000" at position 0

# %%
df['date']= pd.to_datetime(df['date'])
df['date'] = pd.to_numeric(df['date'])

# %%
#check data types
df.dtypes
# Out:
# id                 int64
# date               int64
# price            float64
# bedrooms           int64
# bathrooms          int64
# sqft_living        int64
# sqft_lot           int64
# floors             int64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.corr()
# Out:
#                      id      date     price  bedrooms  bathrooms  sqft_living  \
# id             1.000000  0.005577 -0.016762  0.001286  -0.000038    -0.012258
# date           0.005577  1.000000 -0.004357 -0.016800  -0.029478    -0.034559
# price         -0.016762 -0.004357  1.000000  0.308350   0.510072     0.702035
# bedrooms       0.001286 -0.016800  0.308350  1.000000   0.467452     0.576671
# bathrooms     -0.000038 -0.029478  0.510072  0.467452   1.000000     0.697875
# sqft_living   -0.012258 -0.034559  0.702035  0.576671   0.697875     1.000000
# sqft_lot      -0.132109  0.006313  0.089661  0.031703   0.085310     0.172826
# floors         0.019120 -0.019079  0.237211  0.155643   0.484822     0.353321
# waterfront    -0.002721  0.001356  0.266369 -0.006582   0.058798     0.103818
# view           0.011592 -0.001800  0.397293  0.079532   0.177257     0.284611
# condition     -0.023783 -0.050769  0.036362  0.028472  -0.126016    -0.058753
# grade          0.008130 -0.039912  0.667434  0.356967   0.606631     0.762704
# sqft_above    -0.010842 -0.027924  0.605567  0.477600   0.639933     0.876597
# sqft_basement -0.005151 -0.019469  0.323816  0.303093   0.250880     0.435043
# yr_built       0.021380 -0.000355  0.054012  0.154178   0.433647     0.318049
# yr_renovated  -0.016907 -0.024509  0.126434  0.018841   0.060436     0.055363
# zipcode       -0.008224  0.001404 -0.053203 -0.152668  -0.159773    -0.199430
# lat           -0.001891 -0.032856  0.307003 -0.008931   0.031351     0.052529
# long           0.020799 -0.007020  0.021626  0.129473   0.179351     0.240223
# sqft_living15 -0.002901 -0.031515  0.585379  0.391638   0.510049     0.756420
# sqft_lot15    -0.138798  0.002566  0.082447  0.029244   0.080779     0.183286
#
#                sqft_lot    floors  waterfront      view  ...     grade  \
# id            -0.132109  0.019120   -0.002721  0.011592  ...  0.008130
# date           0.006313 -0.019079    0.001356 -0.001800  ... -0.039912
# price          0.089661  0.237211    0.266369  0.397293  ...  0.667434
# bedrooms       0.031703  0.155643   -0.006582  0.079532  ...  0.356967
# bathrooms      0.085310  0.484822    0.058798  0.177257  ...  0.606631
# sqft_living    0.172826  0.353321    0.103818  0.284611  ...  0.762704
# sqft_lot       1.000000 -0.008951    0.021604  0.074710  ...  0.113621
# floors        -0.008951  1.000000    0.019640  0.024658  ...  0.472608
# waterfront     0.021604  0.019640    1.000000  0.401857  ...  0.082775
# view           0.074710  0.024658    0.401857  1.000000  ...  0.251321
# condition     -0.008958 -0.293173    0.016653  0.045990  ... -0.144674
# grade          0.113621  0.472608    0.082775  0.251321  ...  1.000000
# sqft_above     0.183512  0.517913    0.072075  0.167649  ...  0.755923
# sqft_basement  0.015286 -0.235836    0.080588  0.276947  ...  0.168392
# yr_built       0.053080  0.578619   -0.026161 -0.053440  ...  0.446963
# yr_renovated   0.007644 -0.007775    0.092885  0.103917  ...  0.014414
# zipcode       -0.129574 -0.096743    0.030285  0.084827  ... -0.184862
# lat           -0.085683  0.029567   -0.014274  0.006157  ...  0.114084
# long           0.229521  0.159001   -0.041910 -0.078400  ...  0.198372
# sqft_living15  0.144608  0.296561    0.086463  0.280439  ...  0.713202
# sqft_lot15     0.718557 -0.013252    0.030703  0.072575  ...  0.119248
#
#                sqft_above  sqft_basement  yr_built  yr_renovated   zipcode  \
# id              -0.010842      -0.005151  0.021380     -0.016907 -0.008224
# date            -0.027924      -0.019469 -0.000355     -0.024509  0.001404
# price            0.605567       0.323816  0.054012      0.126434 -0.053203
# bedrooms         0.477600       0.303093  0.154178      0.018841 -0.152668
# bathrooms        0.639933       0.250880  0.433647      0.060436 -0.159773
# sqft_living      0.876597       0.435043  0.318049      0.055363 -0.199430
# sqft_lot         0.183512       0.015286  0.053080      0.007644 -0.129574
# floors           0.517913      -0.235836  0.578619     -0.007775 -0.096743
# waterfront       0.072075       0.080588 -0.026161      0.092885  0.030285
# view             0.167649       0.276947 -0.053440      0.103917  0.084827
# condition       -0.158214       0.174105 -0.361417     -0.060618  0.003026
# grade            0.755923       0.168392  0.446963      0.014414 -0.184862
# sqft_above       1.000000      -0.051943  0.423898      0.023285 -0.261190
# sqft_basement   -0.051943       1.000000 -0.133124      0.071323  0.074845
# yr_built         0.423898      -0.133124  1.000000     -0.224874 -0.346869
# yr_renovated     0.023285       0.071323 -0.224874      1.000000  0.064357
# zipcode         -0.261190       0.074845 -0.346869      0.064357  1.000000
# lat             -0.000816       0.110538 -0.148122      0.029398  0.267048
# long             0.343803      -0.144765  0.409356     -0.068372 -0.564072
# sqft_living15    0.731870       0.200355  0.326229     -0.002673 -0.279033
# sqft_lot15       0.194050       0.017276  0.070958      0.007854 -0.147221
#
#                     lat      long  sqft_living15  sqft_lot15
# id            -0.001891  0.020799      -0.002901   -0.138798
# date          -0.032856 -0.007020      -0.031515    0.002566
# price          0.307003  0.021626       0.585379    0.082447
# bedrooms      -0.008931  0.129473       0.391638    0.029244
# bathrooms      0.031351  0.179351       0.510049    0.080779
# sqft_living    0.052529  0.240223       0.756420    0.183286
# sqft_lot      -0.085683  0.229521       0.144608    0.718557
# floors         0.029567  0.159001       0.296561   -0.013252
# waterfront    -0.014274 -0.041910       0.086463    0.030703
# view           0.006157 -0.078400       0.280439    0.072575
# condition     -0.014941 -0.106500      -0.092824   -0.003406
# grade          0.114084  0.198372       0.713202    0.119248
# sqft_above    -0.000816  0.343803       0.731870    0.194050
# sqft_basement  0.110538 -0.144765       0.200355    0.017276
# yr_built      -0.148122  0.409356       0.326229    0.070958
# yr_renovated   0.029398 -0.068372      -0.002673    0.007854
# zipcode        0.267048 -0.564072      -0.279033   -0.147221
# lat            1.000000 -0.135512       0.048858   -0.086419
# long          -0.135512  1.000000       0.334605    0.254451
# sqft_living15  0.048858  0.334605       1.000000    0.183192
# sqft_lot15    -0.086419  0.254451       0.183192    1.000000
#
# [21 rows x 21 columns]

# %%
correlation = df.corr(method='pearson')
columns = correlation.nlargest(10, 'price').index
columns
# Out:
# Index(['price', 'sqft_living', 'grade', 'sqft_above', 'sqft_living15',
#        'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat'],
#       dtype='object')

# %%
y_data = df['price']

# %%
x_data = df[columns]

# %%
X_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6384/1386402438.py in <module>
# ----> 1 X_data.head()
#
# NameError: name 'X_data' is not defined

# %%
x_data.head()
# Out:
#       price  sqft_living  grade  sqft_above  sqft_living15  bathrooms  view  \
# 0  221900.0         1180      7        1180           1340          1     0
# 1  538000.0         2570      7        2170           1690          2     0
# 2  180000.0          770      6         770           2720          1     0
# 3  604000.0         1960      7        1050           1360          3     0
# 4  510000.0         1680      8        1680           1800          2     0
#
#    sqft_basement  bedrooms      lat
# 0              0         3  47.5112
# 1            400         3  47.7210
# 2              0         2  47.7379
# 3            910         4  47.5208
# 4              0         3  47.6168

# %%
x_data=df.drop('price',axis=1)

# %%
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

# %%
#import libs
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train)
x_test_pr1=pr1.fit_transform(x_test)
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6384/1135506724.py in <module>
# ----> 1 pr1=PolynomialFeatures(degree=2)
#       2 x_train_pr1=pr1.fit_transform(x_train)
#       3 x_test_pr1=pr1.fit_transform(x_test)
#       4 poly1 = LinearRegression()
#       5 poly1.fit(x_train_pr1,y_train)
#
# NameError: name 'PolynomialFeatures' is not defined

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train)
x_test_pr1=pr1.fit_transform(x_test)
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)
# Out:
# LinearRegression()

# %%
yhat_test = poly1.predict(x_test_pr1)

# %%
poly1.score(x_test_pr1, y_test)
# Out:
# 0.533690070127096

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6384/1306152238.py in <module>
# ----> 1 DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
#
# NameError: name 'DistributionPlot' is not defined

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6384/1306152238.py in <module>
# ----> 1 DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
#
# ~\AppData\Local\Temp/ipykernel_6384/2906063618.py in DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title)
#       3     fig, ax = plt.subplots()
#       4     #define first graph style and second graph style
# ----> 5     sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
#       6     sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
#       7
#
# NameError: name 'sns' is not defined

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6384/1306152238.py in <module>
# ----> 1 DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
#
# ~\AppData\Local\Temp/ipykernel_6384/2906063618.py in DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title)
#       3     fig, ax = plt.subplots()
#       4     #define first graph style and second graph style
# ----> 5     sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
#       6     sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
#       7
#
# NameError: name 'sns' is not defined

# %%
import sklearn
from scipy import stats
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
Rsqu_test = []
order = [1, 2, 3, 4]
lr = LinearRegression()
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train)
    x_test_pr = pr.fit_transform(x_test)    
    lr.fit(x_train_pr, y_train)
   
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
# Best order for regression is 2

# %%
plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')

# %%
Rsqu_test = []
order = [1, 2, 3, 4]
lr = LinearRegression()
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train[col_names])
    x_test_pr = pr.fit_transform(x_test[col_names])    
    lr.fit(x_train_pr, y_train)
   
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
