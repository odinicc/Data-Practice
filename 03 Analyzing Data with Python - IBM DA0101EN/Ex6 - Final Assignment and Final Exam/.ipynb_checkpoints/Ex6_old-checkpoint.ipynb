# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv ('kc_house_data.csv')

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df[[date]].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/1509519585.py in <module>
# ----> 1 df[[date]].head(10)
#
# NameError: name 'date' is not defined

# %%
df[[date].head(10)

# %%
df[[date]].head()

# %%
df.loc[:,"date"]

# %%
df2 = pd.to_datetime(df['date'])

# %%
df2.head()

# %%
df.dtypes

# %%
df.dtypes

# %%
df['bedrooms'] = df['bedrooms'].astype(np.int64)

# %%
df['bedrooms'] = df['bedrooms'].astype(int64)

# %%
import numpy as np

# %%
df['bedrooms'] = df['bedrooms'].astype(np.int64)

# %%
df.dtypes

# %%
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

# %%
df.describe()

# %%
missing_data = df.isnull()

# %%
missing_data.head(10)

# %%
missing_data

# %%
missing_data.head(30)

# %%
df.dropna(axis=0, how='any')

# %%
missing_data = df.isnull()

# %%
missing_data

# %%
df = pd.read_csv ('kc_house_data.csv')
print(df)

#check data types
df.dtypes

df.loc[:,"date"]

#convert dates to datetime64 and values to int
df['date']= pd.to_datetime(df['date'])
df['bedrooms'] = df['bedrooms'].astype(np.int64)
df['bathrooms'] = df['bathrooms'].astype(np.int64)
df['floors'] = df['floors'].astype(np.int64)

# %%
missing_data = df.isnull()

# %%
missing_data

# %%
df.dropna(subset=["price"], axis=0, inplace=True)

# %%
df

# %%
df.replace("?", np.nan, inplace = True)
df.head(5)

# %%
missing_data = df.isnull()
missing_data.head(5)

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")

# %%
df.cor()

# %%
df.corr()

# %%
df.drop(['qft_lot, waterfront', 'condition', 'yr_built', 'zipcode', 'long', 'sqft_lot15'], axis=1)

# %%
df.drop(['qft_lot', 'waterfront', 'condition', 'yr_built', 'zipcode', 'long', 'sqft_lot15'], axis=1)

# %%
df.drop([ 'waterfront', 'condition', 'yr_built', 'zipcode', 'long', 'sqft_lot15'], axis=1)

# %%
df.corr()

# %%
df.drop([ 'sqft_lot', 'yr_built'], axis=1)

# %%
df.corr()

# %%
df.describe()

# %%
df.drop([ 'sqft_lot', 'yr_built'], axis=1)

# %%
df.corr()

# %%
df.drop([ 'zipcode'], axis=1)

# %%
df.corr()

# %%
df.drop([ 'sqft_lot', 'yr_built'], inplace=True)df.drop([ 'sqft_lot', 'yr_built'], inplace=True)([ 'long', 'yr_built'], axis=1)

# %%
df.corr()

# %%
df.drop([ 'sqft_lot', 'yr_built'], inplace=True)

# %%
df.head()

# %%
df.drop([ 'yr_built'], inplace=True)

# %%
df = df.drop(['yr_built'], 1)

# %%
df = df.drop(['yr_built'], axis=1)

# %%
df.describe()

# %%
df.drop('long', axis=1, inplace=True)

# %%
df.describe()

# %%
df.corr()

# %%
df.drop(['zipcode','sqft_lot15'] axis=1, inplace=True)

# %%
df.drop(['zipcode','sqft_lot15'], axis=1, inplace=True)

# %%
df.corr()

# %%
df.plot(x='price', y='sqft_living', style='o')

# %%
df.plot(x='price', y='bedrooms', style='o')

# %%
df.plot(x='price', y='sqft_living15', style='o')

# %%
sns.regplot(x="sqft_living15", y="price", data=df)

# %%
import seaborn as sns

# %%
sns.regplot(x="sqft_living15", y="price", data=df)

# %%
df.isnull().sum()

# %%
correlation_map = np.corrcoef(data[columns].values.T)
sns.set(font_scale=1.0)
heatmap = sns.heatmap(correlation_map, cbar=True, annot=True, square=True, fmt='.2f', yticklabels=columns.values, xticklabels=columns.values)

plt.show()

# %%
correlation_map = np.corrcoef(df[columns].values.T)
sns.set(font_scale=1.0)
heatmap = sns.heatmap(correlation_map, cbar=True, annot=True, square=True, fmt='.2f', yticklabels=columns.values, xticklabels=columns.values)

plt.show()

# %%
columns = correlation.nlargest(10, 'price').index

# %%
correlation = data.corr(method='pearson')
columns = correlation.nlargest(10, 'price').index
columns

# %%
correlation = df.corr(method='pearson')
columns = correlation.nlargest(10, 'price').index
columns

# %%
correlation = data.corr(method='pearson')
columns = correlation.nlargest(10, 'price').index
columns

# %%
correlation_map = np.corrcoef(df[columns].values.T)
sns.set(font_scale=1.0)
heatmap = sns.heatmap(correlation_map, cbar=True, annot=True, square=True, fmt='.2f', yticklabels=columns.values, xticklabels=columns.values)

plt.show()

# %%
#plot correlation map
correlation_map = np.corrcoef(df[columns].values.T)
sns.set(font_scale=2.0)
heatmap = sns.heatmap(correlation_map, cbar=True, annot=True, square=True, fmt='.2f', yticklabels=columns.values, xticklabels=columns.values)
plt.show()

# %%
#plot correlation map
correlation_map = np.corrcoef(df[columns].values.T)
sns.set(font_scale=0.5)
heatmap = sns.heatmap(correlation_map, cbar=True, annot=True, square=True, fmt='.2f', yticklabels=columns.values, xticklabels=columns.values)
plt.show()

# %%
#plot correlation map
correlation_map = np.corrcoef(df[columns].values.T)
sns.set(font_scale=0.8)
heatmap = sns.heatmap(correlation_map, cbar=True, annot=True, square=True, fmt='.2f', yticklabels=columns.values, xticklabels=columns.values)
plt.show()

# %%
#place the target data price in a separate dataframe y_data
y_data = df['price']
x_data=df.drop('price',axis=1)

# %%
#get 10% of dataset as test split 
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

# %%
from sklearn import model_selection
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

# %%
from sklearn import model_selection

# %%
    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

# %%
from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[[correlation]])
x_test_pr1=pr1.fit_transform(x_test[[correlation]])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)

# %%
columns

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[[columns]])
x_test_pr1=pr1.fit_transform(x_test[[columns]])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)

# %%
columns

# %%
col_names = correlation.nlargest(10, 'price')

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[[col_names]])
x_test_pr1=pr1.fit_transform(x_test[[col_names]])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)

# %%
col_names

# %%
type(col_names)

# %%
col_names = correlation.nlargest(10, 'price').columns

# %%
col_names

# %%
col_names = list(correlation.nlargest(10, 'price').columns)

# %%
col_names

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[[col_names]])
x_test_pr1=pr1.fit_transform(x_test[[col_names]])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[[col_names]])
x_test_pr1=pr1.fit_transform(x_test[[col_names]])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[[col_names]])
x_test_pr1=pr1.fit_transform(x_test[[col_names]])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)
------------------------

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[col_names])
x_test_pr1=pr1.fit_transform(x_test[col_names])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)

# %%
col_names

# %%
type(col_names)

# %%
col_names.remove('price')

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[col_names])
x_test_pr1=pr1.fit_transform(x_test[col_names])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)

# %%
import sklearn
from sklearn import linear_model

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[col_names])
x_test_pr1=pr1.fit_transform(x_test[col_names])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)

# %%
import sklearn
from sklearn import linear_model

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[col_names])
x_test_pr1=pr1.fit_transform(x_test[col_names])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)

# %%
import numpy as np
from sklearn import linear_model

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[col_names])
x_test_pr1=pr1.fit_transform(x_test[col_names])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[col_names])
x_test_pr1=pr1.fit_transform(x_test[col_names])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)

# %%
from sklearn.linear_model import LinearRegression

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[col_names])
x_test_pr1=pr1.fit_transform(x_test[col_names])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)

# %%
yhat_test = lr.predict(x_test[col_names])

# %%
yhat_test = poly1.predict(x_test[col_names])

# %%
yhat_test = poly1.predict(x_test_pr1)

# %%
yhat_test

# %%
from ipywidgets import interact, interactive, fixed, interact_manual

def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    #define first graph style and second graph style
    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of Cars')
    
    #show plot
    plt.show()
    plt.close()

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",Title)

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
from matplotlib import pyplot as plt

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
yhat_test

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    plt.figure(figsize=('15','12'))
    
    #define first graph style and second graph style
    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    plt.figure(figsize=('15','12'))
    
    #define first graph style and second graph style
    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    plt.figure(figsize=(15,12))
    
    #define first graph style and second graph style
    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    plt.figure(figsize=(15,12))
    
    #define first graph style and second graph style
    sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    
    #define first graph style and second graph style
    sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    
    #define first graph style and second graph style
    sns.distplot(RedFunction, hist=False, rug=True, color="r", label=RedName)
    sns.distplot(BlueFunction, hist=False, rug=True, color="b", label=BlueName)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    
    #define first graph style and second graph style
    sns.displot(RedFunction, hist=False, rug=True, color="r", label=RedName)
    sns.displot(BlueFunction, hist=False, rug=True, color="b", label=BlueName)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    
    #define first graph style and second graph style
    sns.displot(RedFunction, hist=False, rug=True, color="r", label=RedName)
  
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    
    #define first graph style and second graph style
    sns.displot(RedFunction, kind="kde", rug=True, color="r", label=RedName)
    sns.displot(BlueFunction, kind="kde", rug=True, color="b", label=BlueName)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    
    #define first graph style and second graph style
    sns.displot(RedFunction, kind="kde", rug=True, color="r", label=RedName)
    sns.displot(BlueFunction, kind="kde", rug=True, color="b", label=BlueName)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, kind="kde", rug=True, color="r", label=RedName,ax=ax)
    sns.kdeplot(BlueFunction, kind="kde", rug=True, color="b", label=BlueName,ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.sns.set(rc={'figure.figsize':(11.7,8.27)})(RedFunction, ax=ax)
    sns.kdeplot(BlueFunction, ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, label=RedName, ax=ax)
    sns.kdeplot(BlueFunction, ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, label='RedName', ax=ax)
    sns.kdeplot(BlueFunction, ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/141203903.py in <module>
#       1 fig, ax = plt.subplots()
#       2 #define first graph style and second graph style
# ----> 3 sns.kdeplot(RedFunction, label='RedName', ax=ax)
#       4 sns.kdeplot(BlueFunction, ax=ax)
#       5
#
# NameError: name 'RedFunction' is not defined

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, label='RedName', ax=ax)
    sns.kdeplot(BlueFunction, ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, label=RedName, ax=ax)
    sns.kdeplot(BlueFunction, ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.legend()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
# Out:
# No handles with labels found to put in legend.

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, label='RedName', ax=ax)
    sns.kdeplot(BlueFunction, ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    plt.legend()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
# Out:
# No handles with labels found to put in legend.

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, label=RedName, ax=ax)
    sns.kdeplot(BlueFunction, ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    ax.legend()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, label=RedName, ax=ax)
    sns.kdeplot(BlueFunction, ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
   ax.legend(facecolor='yellow', fontsize=14)
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
# Out:
#   File "<tokenize>", line 16
#     ax.legend(facecolor='yellow', fontsize=14)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, label=RedName, ax=ax)
    sns.kdeplot(BlueFunction, ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    ax.legend()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, label=RedName, ax=ax)
    sns.kdeplot(BlueFunction, ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    ax[0].legend()
    ax[1].legend()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/1446494952.py in <module>
#      18     plt.close()
#      19
# ---> 20 DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
#
# ~\AppData\Local\Temp/ipykernel_9716/1446494952.py in DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title)
#      14     #show plot
#      15     plt.show()
# ---> 16     ax[0].legend()
#      17     ax[1].legend()
#      18     plt.close()
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, label=RedName, ax=ax)
    sns.kdeplot(BlueFunction, ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    ax.legend(loc="upper right")
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, label=RedName, ax=ax)
    sns.kdeplot(BlueFunction, ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    fig.legend(labels=['First','Second'])
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, label=RedName, ax=ax)
    sns.kdeplot(BlueFunction, ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    fig.legend(labels=['First','Second'])
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/160441783.py in <module>
#      17     plt.close()
#      18
# ---> 19 DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')
#
# ~\AppData\Local\Temp/ipykernel_9716/160441783.py in DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title)
#       4     ax = plt.subplots()
#       5     #define first graph style and second graph style
# ----> 6     sns.kdeplot(RedFunction, label=RedName, ax=ax)
#       7     sns.kdeplot(BlueFunction, ax=ax)
#       8
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    #define chart size
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax)
    sns.kdeplot(BlueFunction, color='blue', ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    plt.show()
    fig.legend(labels=['First','Second'])
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label='means TP')
    sns.kdeplot(BlueFunction, color='blue', ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax)
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
   
    fig, ax = plt.subplots()
    #define first graph style and second graph style
    sns.kdeplot(RedFunction, color='red', ax=ax, label=RedName)
    sns.kdeplot(BlueFunction, color='blue', ax=ax,label=BlueName )
    
    #define titles and axis
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of flats')
    
    #show plot
    ax.legend()
    plt.show()
    plt.close()

DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
Rsqu_test = []

order = [1, 2, 3, 4]
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train[col_names])
    x_test_pr = pr.fit_transform(x_test[col_names])    
    lr.fit(x_train_pr, y_train)
    
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/1507402114.py in <module>
#       7     x_train_pr = pr.fit_transform(x_train[col_names])
#       8     x_test_pr = pr.fit_transform(x_test[col_names])
# ----> 9     lr.fit(x_train_pr, y_train)
#      10
#      11     Rsqu_test.append(lr.score(x_test_pr, y_test))
#
# NameError: name 'lr' is not defined

# %%
Rsqu_test = []

order = [1, 2, 3, 4]
lr = LinearRegression()
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train[col_names])
    x_test_pr = pr.fit_transform(x_test[col_names])    
    lr.fit(x_train_pr, y_train)
   
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
# Out:
# Text(0.5, 1.0, 'R^2 Using Test Data')

# %%
parameters= [{'alpha': [0.001,0.1,1, 10, 100, 1000,10000,100000,100000]} ]
Grid2 = GridSearchCV(Ridge(), parameters,cv=4)
Grid2.fit(x_data[col_names],y_data)
Grid2.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/1939326627.py in <module>
#       1 parameters= [{'alpha': [0.001,0.1,1, 10, 100, 1000,10000,100000,100000]} ]
# ----> 2 Grid2 = GridSearchCV(Ridge(), parameters,cv=4)
#       3 Grid2.fit(x_data[col_names],y_data)
#       4 Grid2.best_estimator_
#
# NameError: name 'GridSearchCV' is not defined

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters= [{'alpha': [0.001,0.1,1, 10, 100, 1000,10000,100000,100000]} ]
Grid2 = GridSearchCV(Ridge(), parameters,cv=4)
Grid2.fit(x_data[col_names],y_data)
Grid2.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/1939326627.py in <module>
#       1 parameters= [{'alpha': [0.001,0.1,1, 10, 100, 1000,10000,100000,100000]} ]
# ----> 2 Grid2 = GridSearchCV(Ridge(), parameters,cv=4)
#       3 Grid2.fit(x_data[col_names],y_data)
#       4 Grid2.best_estimator_
#
# NameError: name 'Ridge' is not defined

# %%
from sklearn import linear_model

# %%
from sklearn.linear_model import Ridge

# %%
parameters= [{'alpha': [0.001,0.1,1, 10, 100, 1000,10000,100000,100000]} ]
Grid2 = GridSearchCV(Ridge(), parameters,cv=4)
Grid2.fit(x_data[col_names],y_data)
Grid2.best_estimator_
# Out:
# C:\Users\ivan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.45395e-27): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\ivan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.42486e-27): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\ivan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.44235e-27): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\ivan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.48947e-27): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# ...

# %%
Grid2.best_estimator_
# Out:
# Ridge(alpha=1)

# %%
Ridge(normalize=True)
# Out:
# Ridge(normalize=True)

# %%
parameters= [{'alpha': [0.001,0.1,1, 10, 100, 1000,10000,100000,100000]} ]
Grid2 = GridSearchCV(Ridge(), parameters,cv=4)
Grid2.fit(x_data[col_names],y_data)
Grid2.best_estimator_
# Out:
# C:\Users\ivan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.45395e-27): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\ivan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.42486e-27): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\ivan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.44235e-27): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\ivan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.48947e-27): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# ...

# %%
parameters= [{'alpha': [0.001,0.1,1, 10, 100, 1000,10000,100000,100000],'normalize':[True]} ]
Grid2 = GridSearchCV(Ridge(), parameters,cv=4)
Grid2.fit(x_data[col_names],y_data)
Grid2.best_estimator_
# Out:
# Ridge(alpha=0.001, normalize=True)

# %%
parameters= [{'alpha': [0.001,0.1,1, 10, 100, 1000,10000,100000,100000],'normalize':[True,False]} ]
Grid2 = GridSearchCV(Ridge(), parameters,cv=4)
Grid2.fit(x_data[col_names],y_data)
Grid2.best_estimator_
# Out:
# C:\Users\ivan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.45395e-27): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\ivan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.42486e-27): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\ivan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.44235e-27): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\ivan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.48947e-27): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# ...

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[col_names])
x_test_pr1=pr1.fit_transform(x_test[col_names])
poly1 = LinearRegression()
poly1.fit(x_train_pr1,y_train)
yhat_test = poly1.predict(x_test_pr1)

# %%
poly1.score(x_test_pr1, y_test
# Out:
#   File "C:\Users\ivan\AppData\Local\Temp/ipykernel_9716/2766442308.py", line 1
#     poly1.score(x_test_pr1, y_test
#                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
poly1.score(x_test_pr1, y_test)
# Out:
# 0.7026694643543289

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[col_names])
x_test_pr1=pr1.fit_transform(x_test[col_names])
RigeModel = Ridge(alpha=0.001) 
RigeModel.fit(x_train_pr1,y_train)
yhat_test = RigeModel.predict(x_test_pr1)

#calcaulate R2
RigeModel.score(x_test_pr1, y_test)

#R2 = 0.7026694643543289
# Out:
# 0.44134590479135394

# %%
RigeModel.score(x_test_pr1, y_test)
# Out:
# 0.44134590479135394

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[col_names])
x_test_pr1=pr1.fit_transform(x_test[col_names])
RigeModel = Ridge(alpha=0.001, normalize=True)
RigeModel.fit(x_train_pr1,y_train)
yhat_test = RigeModel.predict(x_test_pr1)

#calcaulate R2
RigeModel.score(x_test_pr1, y_test)
# Out:
# 0.7763675502772127

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
describe(y.date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/686686551.py in <module>
# ----> 1 describe(y.date)
#
# NameError: name 'describe' is not defined

# %%
y.data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/208161183.py in <module>
# ----> 1 y.data
#
# NameError: name 'y' is not defined

# %%
y_data
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
pr1=PolynomialFeatures(degree=2)
x_train_pr1=pr1.fit_transform(x_train[col_names])
x_test_pr1=pr1.fit_transform(x_test[col_names])
RigeModel = Ridge(alpha=0.001, normalize=True)
RigeModel.fit(x_train_pr1,y_train)
yhat_test = RigeModel.predict(x_test_pr1)

#calcaulate R2
RigeModel.score(x_test_pr1, y_test)
# Out:
# 0.7763675502772127

# %%
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.datasets import load_diabetes
HistGradientBoostingRegressor().fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/2434820459.py in <module>
# ----> 1 from sklearn.ensemble import HistGradientBoostingRegressor
#       2 from sklearn.datasets import load_diabetes
#       3 HistGradientBoostingRegressor().fit(x_train,y_train)
#
# ImportError: cannot import name 'HistGradientBoostingRegressor' from 'sklearn.ensemble' (C:\Users\ivan\anaconda3\lib\site-packages\sklearn\ensemble\__init__.py)

# %%
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.datasets import load_diabetes
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/2860583743.py in <module>
# ----> 1 from sklearn.ensemble import HistGradientBoostingRegressor
#       2 from sklearn.datasets import load_diabetes
#
# ImportError: cannot import name 'HistGradientBoostingRegressor' from 'sklearn.ensemble' (C:\Users\ivan\anaconda3\lib\site-packages\sklearn\ensemble\__init__.py)

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
HistGradientBoostingRegressor().fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/2896358235.py in <module>
# ----> 1 HistGradientBoostingRegressor().fit(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py in fit(self, X, y, sample_weight)
#     200         # time spent predicting X for gradient and hessians update
#     201         acc_prediction_time = 0.
# --> 202         X, y = self._validate_data(X, y, dtype=[X_DTYPE],
#     203                                    force_all_finite=False)
#     204         y = self._encode_y(y)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
x_train_pr1=pr1.fit_transform(x_train[col_names])
HistGradientBoostingRegressor().fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/1493514436.py in <module>
#       1 x_train_pr1=pr1.fit_transform(x_train[col_names])
# ----> 2 HistGradientBoostingRegressor().fit(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py in fit(self, X, y, sample_weight)
#     200         # time spent predicting X for gradient and hessians update
#     201         acc_prediction_time = 0.
# --> 202         X, y = self._validate_data(X, y, dtype=[X_DTYPE],
#     203                                    force_all_finite=False)
#     204         y = self._encode_y(y)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...

# %%
type(x_train_pr1)
# Out:
# numpy.ndarray

# %%
describe(x_train_pr1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/3789258010.py in <module>
# ----> 1 describe(x_train_pr1)
#
# NameError: name 'describe' is not defined

# %%
x_train_pr1.dtype
# Out:
# dtype('float64')

# %%
col_names
# Out:
# ['id',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_renovated',
#  'lat',
#  'sqft_living15']

# %%
x_train.head()
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 16973  5561301150 2014-11-11         5          3         3520     36558
# 14689  8712100760 2014-09-24         2          1         1790      4250
# 819    1565900070 2014-07-21         3          2         1430      8919
# 20246  9376301112 2014-10-31         2          2         1380      1329
# 8084   8146100325 2014-05-05         3          1         1330      7500
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 16973       2           0     0          4      8        2100           1420
# 14689       1           0     0          3      7         920            870
# 819         1           0     0          3      7        1430              0
# 20246       2           0     0          3      8        1050            330
# 8084        1           0     0          3      8        1330              0
#
#        yr_renovated      lat  sqft_living15
# ...

# %%
x_train.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/3778083001.py in <module>
# ----> 1 x_train.dtype
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
type(x_train)
# Out:
# pandas.core.frame.DataFrame

# %%
x_train.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# bedrooms                  int64
# bathrooms                 int64
# sqft_living               int64
# sqft_lot                  int64
# floors                    int64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_renovated              int64
# lat                     float64
# sqft_living15             int64
# dtype: object

# %%
x_train.haed()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/3619728000.py in <module>
# ----> 1 x_train.haed()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'haed'

# %%
x_train.head()
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 16973  5561301150 2014-11-11         5          3         3520     36558
# 14689  8712100760 2014-09-24         2          1         1790      4250
# 819    1565900070 2014-07-21         3          2         1430      8919
# 20246  9376301112 2014-10-31         2          2         1380      1329
# 8084   8146100325 2014-05-05         3          1         1330      7500
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 16973       2           0     0          4      8        2100           1420
# 14689       1           0     0          3      7         920            870
# 819         1           0     0          3      7        1430              0
# 20246       2           0     0          3      8        1050            330
# 8084        1           0     0          3      8        1330              0
#
#        yr_renovated      lat  sqft_living15
# ...

# %%
col_names2 = col_names.remove('date')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/1807291703.py in <module>
# ----> 1 col_names2 = col_names.remove('date')
#
# ValueError: list.remove(x): x not in list

# %%
df['date'].str.replace('\D', '').astype(int)
# Out:
# C:\Users\ivan\AppData\Local\Temp/ipykernel_9716/1302397426.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['date'].str.replace('\D', '').astype(int)
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/1302397426.py in <module>
# ----> 1 df['date'].str.replace('\D', '').astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
# ...

# %%
df[‘dateint’] = pd.to_datetime(df[‘date’], 
 format = ‘%Y-%m-%dT%H:%M:%SZ’)
# Out:
#   File "C:\Users\ivan\AppData\Local\Temp/ipykernel_9716/1132982915.py", line 1
#     df[‘dateint’] = pd.to_datetime(df[‘date’],
#        ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
df['dateint'] = pd.to_datetime(df['date'], 
 format = '%Y-%m-%dT%H:%M:%SZ')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/3897578312.py in <module>
# ----> 1 df['dateint'] = pd.to_datetime(df['date'],
#       2  format = '%Y-%m-%dT%H:%M:%SZ')
#
# ...

# %%
df['dateint'] = pd.to_datetime(df['date'])

# %%
df.head
# Out:
# <bound method NDFrame.head of                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# ...

# %%
#plot correlation map
correlation_map = np.corrcoef(df[columns].values.T)
sns.set(font_scale=1.0)
heatmap = sns.heatmap(correlation_map, cbar=True, annot=True, square=True, fmt='.2f', yticklabels=columns.values, xticklabels=columns.values)
plt.show()

# %%
#plot correlation map
correlation_map = np.corrcoef(df[].values.T)
sns.set(font_scale=1.0)
heatmap = sns.heatmap(correlation_map, cbar=True, annot=True, square=True, fmt='.2f', yticklabels=columns.values, xticklabels=columns.values)
plt.show()
# Out:
#   File "C:\Users\ivan\AppData\Local\Temp/ipykernel_9716/2834472473.py", line 2
#     correlation_map = np.corrcoef(df[].values.T)
#                                      ^
# SyntaxError: invalid syntax

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
df.types()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/1697157781.py in <module>
# ----> 1 df.types()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'types'

# %%
df.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/2465499897.py in <module>
# ----> 1 df.type()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
df.dtypes
# Out:
# id                        int64
# date                     object
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dateint          datetime64[ns]
# dtype: object

# %%
df['dint'] = pd.to_datetime(df['dateint']).astype(np.int64)
# Out:
# C:\Users\ivan\AppData\Local\Temp/ipykernel_9716/2431659448.py:1: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   df['dint'] = pd.to_datetime(df['dateint']).astype(np.int64)

# %%
df['dateint'] = pd.to_numeric(df['date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "20141013T000000"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/2793312676.py in <module>
# ----> 1 df['dateint'] = pd.to_numeric(df['date'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
df['dateint1'] = pd.to_numeric(df['dateint'])

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode  \
# 0      5650     1.0           0     0  ...      1955             0    98178
# 1      7242     2.0           0     0  ...      1951          1991    98125
# 2     10000     1.0           0     0  ...      1933             0    98028
# 3      5000     1.0           0     0  ...      1965             0    98136
# 4      8080     1.0           0     0  ...      1987             0    98074
#
# ...

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
dfn=(df-df.mean())/df.std()
# Out:
# C:\Users\ivan\AppData\Local\Temp/ipykernel_9716/1170430066.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   dfn=(df-df.mean())/df.std()
# C:\Users\ivan\AppData\Local\Temp/ipykernel_9716/1170430066.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dfn=(df-df.mean())/df.std()
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/1170430066.py in <module>
# ----> 1 dfn=(df-df.mean())/df.std()
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ...

# %%
df.datatype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/3572740462.py in <module>
# ----> 1 df.datatype
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'datatype'

# %%
df.datatype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/3068054140.py in <module>
# ----> 1 df.datatype()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'datatype'

# %%
df.dtypes
# Out:
# id                        int64
# date                     object
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dateint          datetime64[ns]
# dint                      int64
# dateint1                  int64
# dtype: object

# %%
df.drop(['dintent','date'] axis=1, inplace=True)
# Out:
#   File "C:\Users\ivan\AppData\Local\Temp/ipykernel_9716/3682848998.py", line 1
#     df.drop(['dintent','date'] axis=1, inplace=True)
#                                ^
# SyntaxError: invalid syntax

# %%
df.drop(['zipcode','sqft_lot15'], axis=1, inplace=True)

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/2157385015.py in <module>
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df.dtypes
# Out:
# id                        int64
# date                     object
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# dateint          datetime64[ns]
# dint                      int64
# dateint1                  int64
# dtype: object

# %%
df.drop([dateint'], axis=1, inplace=True)
# Out:
#   File "C:\Users\ivan\AppData\Local\Temp/ipykernel_9716/2030884257.py", line 1
#     df.drop([dateint'], axis=1, inplace=True)
#                                               ^
# SyntaxError: EOL while scanning string literal

# %%
df.drop(['dateint'], axis=1, inplace=True)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
dfn=(df-df.mean())/df.std()
# Out:
# C:\Users\ivan\AppData\Local\Temp/ipykernel_9716/1170430066.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dfn=(df-df.mean())/df.std()

# %%
dfn.corr()
# Out:
#                bathrooms  bedrooms  condition  dateint1      dint    floors  \
# bathrooms       1.000000  0.515884  -0.124982 -0.034410 -0.034410  0.500653
# bedrooms        0.515884  1.000000   0.028472 -0.016800 -0.016800  0.175429
# condition      -0.124982  0.028472   1.000000 -0.050769 -0.050769 -0.263768
# dateint1       -0.034410 -0.016800  -0.050769  1.000000  1.000000 -0.022491
# dint           -0.034410 -0.016800  -0.050769  1.000000  1.000000 -0.022491
# floors          0.500653  0.175429  -0.263768 -0.022491 -0.022491  1.000000
# grade           0.664983  0.356967  -0.144674 -0.039912 -0.039912  0.458183
# id              0.005160  0.001286  -0.023783  0.005577  0.005577  0.018525
# lat             0.024573 -0.008931  -0.014941 -0.032856 -0.032856  0.049614
# long            0.223042  0.129473  -0.106500 -0.007020 -0.007020  0.125419
# price           0.525138  0.308350   0.036362 -0.004357 -0.004357  0.256794
# ...

# %%
col_names = list(correlation.nlargest(10, 'price').columns)
col_names.remove('price')

# %%
col_names.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/2287960159.py in <module>
# ----> 1 col_names.dtype
#
# AttributeError: 'list' object has no attribute 'dtype'

# %%
col_names
# Out:
# ['id',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_renovated',
#  'lat',
#  'sqft_living15']

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingRegressor

x_train_pr1=pr1.fit_transform(x_train[col_names])
HistGradientBoostingRegressor().fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/2063736850.py in <module>
#       3
#       4 x_train_pr1=pr1.fit_transform(x_train[col_names])
# ----> 5 HistGradientBoostingRegressor().fit(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py in fit(self, X, y, sample_weight)
#     200         # time spent predicting X for gradient and hessians update
#     201         acc_prediction_time = 0.
# --> 202         X, y = self._validate_data(X, y, dtype=[X_DTYPE],
#     203                                    force_all_finite=False)
#     204         y = self._encode_y(y)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...

# %%
HistGradientBoostingRegressor().fit(x_train[col_names],y_train)
# Out:
# HistGradientBoostingRegressor()

# %%
HistGradientBoostingRegressor.score(x_test_pr1, y_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/3793077434.py in <module>
# ----> 1 HistGradientBoostingRegressor.score(x_test_pr1, y_test)
#
# TypeError: score() missing 1 required positional argument: 'y'

# %%
HCBR_Model = HistGradientBoostingRegressor()
HCBR_Model.fit(x_train[col_names],y_train)
# Out:
# HistGradientBoostingRegressor()

# %%
HCBR_Model.score(x_test_pr1, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/2414022213.py in <module>
# ----> 1 HCBR_Model.score(x_test_pr1, y_test)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     551
#     552         from .metrics import r2_score
# --> 553         y_pred = self.predict(X)
#     554         return r2_score(y, y_pred, sample_weight=sample_weight)
#     555
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py in predict(self, X)
#    1086         # Return inverse link of raw predictions after converting
#    1087         # shape (n_samples, 1) to (n_samples,)
# -> 1088         return self._loss.inverse_link_function(self._raw_predict(X).ravel())
#    1089
#    1090     def staged_predict(self, X):
#
# ...

# %%
    x_train_pr1=pr1.fit_transform(x_train[col_names])
    x_test_pr1=pr1.fit_transform(x_test[col_names])

# %%
HCBR_Model.score(x_test_pr1, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/2414022213.py in <module>
# ----> 1 HCBR_Model.score(x_test_pr1, y_test)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     551
#     552         from .metrics import r2_score
# --> 553         y_pred = self.predict(X)
#     554         return r2_score(y, y_pred, sample_weight=sample_weight)
#     555
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py in predict(self, X)
#    1086         # Return inverse link of raw predictions after converting
#    1087         # shape (n_samples, 1) to (n_samples,)
# -> 1088         return self._loss.inverse_link_function(self._raw_predict(X).ravel())
#    1089
#    1090     def staged_predict(self, X):
#
# ...

# %%
HCBR_Model = HistGradientBoostingRegressor()
x_train = x_train[col_names]
x_test =x_test[col_names]

# %%
HCBR_Model.fit(x_train,y_train)
# Out:
# HistGradientBoostingRegressor()

# %%
HCBR_Model.score(x_test_pr1, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/2414022213.py in <module>
# ----> 1 HCBR_Model.score(x_test_pr1, y_test)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     551
#     552         from .metrics import r2_score
# --> 553         y_pred = self.predict(X)
#     554         return r2_score(y, y_pred, sample_weight=sample_weight)
#     555
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py in predict(self, X)
#    1086         # Return inverse link of raw predictions after converting
#    1087         # shape (n_samples, 1) to (n_samples,)
# -> 1088         return self._loss.inverse_link_function(self._raw_predict(X).ravel())
#    1089
#    1090     def staged_predict(self, X):
#
# ...

# %%
HCBR_Model.score(x_test_, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/4114998539.py in <module>
# ----> 1 HCBR_Model.score(x_test_, y_test)
#
# NameError: name 'x_test_' is not defined

# %%
HCBR_Model.score(x_test, y_test)
# Out:
# 0.833459690961462

# %%
HCBR_Model = HistGradientBoostingRegressor()
x_train_pr = x_train[col_names]
x_test_pr =x_test[col_names]
HCBR_Model.fit(x_train_pr,y_train_pr)

HCBR_Model.score(x_test_pr1, y_test)
yhat_test = HCBR_Model.predict(x_test_pr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/2534848255.py in <module>
#       2 x_train_pr = x_train[col_names]
#       3 x_test_pr =x_test[col_names]
# ----> 4 HCBR_Model.fit(x_train_pr,y_train_pr)
#       5
#       6 HCBR_Model.score(x_test_pr1, y_test)
#
# NameError: name 'y_train_pr' is not defined

# %%
HCBR_Model = HistGradientBoostingRegressor()
x_train_pr = x_train[col_names]
x_test_pr =x_test[col_names]
HCBR_Model.fit(x_train_pr,y_train)

HCBR_Model.score(x_test_pr1, y_test)
yhat_test = HCBR_Model.predict(x_test_pr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/1830782875.py in <module>
#       4 HCBR_Model.fit(x_train_pr,y_train)
#       5
# ----> 6 HCBR_Model.score(x_test_pr1, y_test)
#       7 yhat_test = HCBR_Model.predict(x_test_pr)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     551
#     552         from .metrics import r2_score
# --> 553         y_pred = self.predict(X)
#     554         return r2_score(y, y_pred, sample_weight=sample_weight)
#     555
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py in predict(self, X)
#    1086         # Return inverse link of raw predictions after converting
#    1087         # shape (n_samples, 1) to (n_samples,)
# -> 1088         return self._loss.inverse_link_function(self._raw_predict(X).ravel())
#    1089
# ...

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
x_train_pr = x_train[col_names]
x_test_pr =x_test[col_names]
HCBR_Model.fit(x_train_pr,y_train)

HCBR_Model.score(x_test_pr1, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/579164595.py in <module>
#       3 HCBR_Model.fit(x_train_pr,y_train)
#       4
# ----> 5 HCBR_Model.score(x_test_pr1, y_test)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     551
#     552         from .metrics import r2_score
# --> 553         y_pred = self.predict(X)
#     554         return r2_score(y, y_pred, sample_weight=sample_weight)
#     555
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py in predict(self, X)
#    1086         # Return inverse link of raw predictions after converting
#    1087         # shape (n_samples, 1) to (n_samples,)
# -> 1088         return self._loss.inverse_link_function(self._raw_predict(X).ravel())
#    1089
#    1090     def staged_predict(self, X):
#
# ...

# %%
x_train
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 16973  5561301150         5          3         3520     36558       2
# 14689  8712100760         2          1         1790      4250       1
# 819    1565900070         3          2         1430      8919       1
# 20246  9376301112         2          2         1380      1329       2
# 8084   8146100325         3          1         1330      7500       1
# ...           ...       ...        ...          ...       ...     ...
# 10955  3630110510         3          2         1920      3867       2
# 17289  6813600605         4          4         3420      7440       3
# 5192    224069145         3          1         1970     54450       1
# 12172   520700125         3          2         1980      8775       1
# 235    1762600320         5          4         3760     28040       2
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
x_train.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/3778083001.py in <module>
# ----> 1 x_train.dtype
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
x_train.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/13752799.py in <module>
# ----> 1 x_train.dtype()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
x_train_pr = x_train[col_names]
x_test_pr =x_test[col_names]
HCBR_Model.fit(x_train_pr,y_train)

HCBR_Model.score(x_test_pr1, y_test)
HCBR_Model.fit(x_train,y_train)
yhat_test = HCBR_Model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/1360525884.py in <module>
#       3 HCBR_Model.fit(x_train_pr,y_train)
#       4
# ----> 5 HCBR_Model.score(x_test_pr1, y_test)
#       6 HCBR_Model.fit(x_train,y_train)
#       7 yhat_test = HCBR_Model.predict(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     551
#     552         from .metrics import r2_score
# --> 553         y_pred = self.predict(X)
#     554         return r2_score(y, y_pred, sample_weight=sample_weight)
#     555
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py in predict(self, X)
#    1086         # Return inverse link of raw predictions after converting
#    1087         # shape (n_samples, 1) to (n_samples,)
# ...

# %%
HCBR_Model = HistGradientBoostingRegressor()
HCBR_Model.fit(x_train[col_names],y_train)
HCBR_Model.score(x_test[col_names], y_test)

yhat_test = HCBR_Model.predict(x_test[col_names])

# %%
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",'hi')

# %%
HCBR_Model.score(x_test[col_names], y_test)
# Out:
# 0.8454376421649572
